# %% [markdown]
# NER on BERT implemented based on:
#
# Reference: https://towardsdatascience.com/named-entity-recognition-with-bert-in-pytorch-a454405e0b6a

# %% [markdown]
# Combining two datasets

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 4.6 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 45.5 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 70.2 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
import pandas as pd
import torch 
import numpy as np
from transformers import BertTokenizerFast, BertForTokenClassification, AdamW, BertConfig
from torch.utils.data import DataLoader
from tqdm import tqdm
from torch.optim import SGD

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.7.1-py3-none-any.whl (451 kB)
#      |████████████████████████████████| 451 kB 4.7 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 95.6 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.11.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (6.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 74.9 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (2.23.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 95.3 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, responses, multiprocess, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.7.1 multiprocess-0.70.14 responses-0.18.0 urllib3-1.25.11 xxhash-3.1.0

# %%
from datasets import load_dataset, load_metric, concatenate_datasets
datasets = load_dataset("Babelscape/wikineural")
# Out:
# Downloading readme:   0%|          | 0.00/5.27k [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration Babelscape--wikineural-579d1dc98d2a6b93
# Downloading and preparing dataset parquet/Babelscape--wikineural to /root/.cache/huggingface/datasets/Babelscape___parquet/Babelscape--wikineural-579d1dc98d2a6b93/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files #15:   0%|          | 0/1 [00:00<?, ?obj/s]
# Downloading data files #7:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #0:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #1:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #12:   0%|          | 0/1 [00:00<?, ?obj/s]
# Downloading data files #2:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #5:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #11:   0%|          | 0/1 [00:00<?, ?obj/s]
# Downloading data files #3:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #13:   0%|          | 0/1 [00:00<?, ?obj/s]
# Downloading data files #10:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #8:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #6:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #9:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #4:   0%|          | 0/2 [00:00<?, ?obj/s]
# Downloading data files #14:   0%|          | 0/1 [00:00<?, ?obj/s]
# Downloading data:   0%|          | 0.00/841k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/702k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/943k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.05M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.12M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/894k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/993k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/706k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/723k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.12M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.43M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.04M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/853k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.18M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.31M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/849k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.52M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.81M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/847k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.31M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/997k [00:00<?, ?B/s]
# Extracting data files #3:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #6:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #14:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #4:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #2:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #9:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #8:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #12:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #13:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #11:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #10:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #7:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #5:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #0:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #1:   0%|          | 0/2 [00:00<?, ?obj/s]
# Extracting data files #15:   0%|          | 0/1 [00:00<?, ?obj/s]
# Generating train_ru split: 0 examples [00:00, ? examples/s]
# Generating test_de split: 0 examples [00:00, ? examples/s]
# Generating val_fr split: 0 examples [00:00, ? examples/s]
# Generating train_en split: 0 examples [00:00, ? examples/s]
# Generating test_en split: 0 examples [00:00, ? examples/s]
# Generating train_fr split: 0 examples [00:00, ? examples/s]
# Generating train_pt split: 0 examples [00:00, ? examples/s]
# Generating test_ru split: 0 examples [00:00, ? examples/s]
# Generating test_it split: 0 examples [00:00, ? examples/s]
# Generating test_pt split: 0 examples [00:00, ? examples/s]
# Generating val_nl split: 0 examples [00:00, ? examples/s]
# Generating val_de split: 0 examples [00:00, ? examples/s]
# Generating val_ru split: 0 examples [00:00, ? examples/s]
# Generating train_pl split: 0 examples [00:00, ? examples/s]
# Generating test_es split: 0 examples [00:00, ? examples/s]
# Generating train_it split: 0 examples [00:00, ? examples/s]
# Generating train_de split: 0 examples [00:00, ? examples/s]
# Generating train_nl split: 0 examples [00:00, ? examples/s]
# Generating train_es split: 0 examples [00:00, ? examples/s]
# Generating test_fr split: 0 examples [00:00, ? examples/s]
# Generating val_pl split: 0 examples [00:00, ? examples/s]
# Generating val_en split: 0 examples [00:00, ? examples/s]
# Generating val_it split: 0 examples [00:00, ? examples/s]
# Generating test_pl split: 0 examples [00:00, ? examples/s]
# Generating test_nl split: 0 examples [00:00, ? examples/s]
# Generating val_es split: 0 examples [00:00, ? examples/s]
# Generating val_pt split: 0 examples [00:00, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/Babelscape___parquet/Babelscape--wikineural-579d1dc98d2a6b93/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
texts = []
for i in datasets["train_en"]:
    i['tokens'] = ' '.join(i['tokens'])
    texts.append(i['tokens'])

# %%
texts
# Out:
# ['This division also contains the Ventana Wilderness , home to the California condor .',
#  '" So here is the balance NBC has to consider : The Who , \' Animal Practice \' .',
#  'It is a protest song that " creates a cinematic vista that tells of the singer \'s search for a literal and physical America that seems to have disappeared , along with the country \'s beauty and ideals " .',
#  'This differs from approaches such as IP or Ethernet that use variable sized packets or frames .',
#  'Since then , only Terry Bradshaw in 147 games , Joe Montana in 139 games , and Tom Brady in 131 games have reached 100 wins more quickly .',
#  'Next is the Adolf-Hitler-Platz , a grand public square for rallies and such .',
#  'Although the name " Minor 1000 " was retained , the changes were sufficient for the new model to be given its own ADO development number .',
#  "But cutting ties with Taiwan was a sad and painful decision because of the friendship between Nicaragua and Taiwan 's people and government .",
#  'In a lower-speed link , such as a 1.544 Mbit / s T1 line , the same packet would take up to 7.8 milliseconds .',
#  'These reductions in market risk " were concentrated in firms domiciled in the eurozone and in non-euro firms with a high fraction of foreign sales or assets in Europe " .',
#  'The highway currently ends near the Ploče sea port , but is planned to continue further on to Dubrovnik .',
#  'The most common definition of continental Europe excludes continental islands , encompassing the Greek Islands , Cyprus , Malta , Sicily , Sardinia , Corsica , the Balearic Islands , Great Britain and Ireland and surrounding islands , Novaya Zemlya and the Nordic archipelago , as well as nearby oceanic islands , including the Canary Islands , Madeira , the Azores , Iceland , the Faroe Islands , and Svalbard .',
#  'It has a leaf pattern similar to the members of the genera " Kedrostis " , " Melothria " and " Zehneria " .',
#  'A 1500 byte ( 12000-bit ) full-size Ethernet frame takes only 1.2 µs to transmit on a 10 Gbit / s network , reducing the need for small cells to reduce jitter due to contention .',
#  'The Kiffians were responsible for a life-size rock engraving of two giraffes , dated 8,000 years ago , that has been called the " world \'s largest rock art petroglyph " .',
#  'He was portrayed by Anthony Perkins in the 1960 version of " Psycho " directed by Alfred Hitchcock and the " Psycho " franchise .',
#  'The egg eventually hatches , revealing a baby Sharptooth .',
#  'Both Serbian and Hungarian are officially used by municipal authorities .',
#  'Some consider that this makes a case for replacing ATM with Ethernet in the network backbone .',
#  'In 2008 , Sochaux bought the player outright .',
#  'It is often served one or two days after Christmas and on other special occasions .',
#  'In February 2020 , he was appointed head coach of the Knights franchise for the upcoming 2020 / 21 season .',
#  'In the video Kelis is walking down a street in a large space suit-style coat , then singing to the stars .',
#  'At these lower speeds , ATM provides a useful ability to carry multiple logical circuits on a single physical or virtual medium , although other techniques exist , such as Multi-link PPP and Ethernet VLANs , which are optional in VDSL implementations .',
#  'he then returned to the first team against Middlesbrough on 12 September 2009 .',
#  'In addition , Bellerive Oval regularly hosts international cricket matches .',
#  'According to food writer Sharon Tyler Herbst , " pico de gallo " ( " rooster \'s beak " ) is named thus because originally people ate it by pinching pieces between the thumb and forefinger .',
#  'Atalanta relegated again in June 2005 .',
#  'PNNI is a link-state routing protocol like OSPF and IS-IS .',
#  'is a high mountain pass in the Canadian Rockies on the border between Alberta and British Columbia .',
#  'He was one of eleven new players brought in by the Sicilian club , during the 2008 summer transfer window .',
#  'After a decade of tumultuous federalism , Ecuador and Venezuela seceded from Gran Colombia in 1830 , leaving the similarly tumultuous United States of Colombia , now the Republic of Colombia which also lost Panama in 1903 .',
#  'Hence , while Mizo when translated means highlanders or people living in high hills , the term specifically denotes a person with Zo ethnic belongingness ( Mizo literally means " A Zo person " ) .',
#  'Companies such as FORE Systems focused on ATM products , while other large vendors such as Cisco Systems provided ATM as an option .',
#  "Kalamazoo was chosen as the new school 's location on August 28 , 1903 .",
#  'After losing the second game , England collapsed to 127 in the third T20I as England lost the series 2 – 1 .',
#  'In this way Plato indicated his high opinion of geometry .',
#  'The " Seventh-day Adventist Church " , founded in 1863 , had over 19,500,000 baptized members ( not counting children of members ) worldwide as of June 2016 .',
#  'However , in 2005 the ATM Forum , which had been the trade organization promoting the technology , merged with groups promoting other technologies , and eventually became the Broadband Forum .',
#  'Also to the east are the brownstones of Hamilton Heights .',
#  'For Spanish-speaking countries , all foreign-language programs , films , cartoons and documentaries shown on free-to-air TV networks are dubbed into Standard Spanish , while broadcasts on cable and satellite pan-regional channels are either dubbed or subtitled .',
#  'Metallurgical products movement are more than one million tons per year and maize exports to Spain vary between 800,000 and 1 million tons .',
#  'Although originally devised in the United States , it was more commonly adopted by British libraries .',
#  'In the early 1990 s , Bell Labs and NEC research labs worked actively in this field .',
#  'Elephantidae is the only surviving family of the order Proboscidea ; extinct members include the mastodons .',
#  'The hero of " Searching for Bobby Fischer " struggles against adopting the aggressive and misanthropic views of a world chess champion .',
#  'The " politics of Canada " function within a framework of parliamentary democracy and a federal system of parliamentary government with strong democratic traditions .',
#  'Colombia has begun to innovate in military technology for its army and other armies of the world ; especially in the design and creation of personal ballistic protection products , military hardware , military robots , bombs , simulators and radar .',
#  'The forum was supported by several telecommunication companies , including NEC , Fujitsu and AT&T .',
#  'Nonetheless , ethnic identity was a significant component of life in Chad .',
#  'In addition , Mayotte became an overseas department and a region of France in 2011 following a referendum passed overwhelmingly .',
#  'Two of these highland groups , the Rade and the Jarai , are Chamic peoples who speak Austronesian languages descended from ancient Cham .',
#  'though the concept was known before that and was studied by many chemists including Avogadro .',
#  'The " anus " ( from Latin " anus " meaning " ring " , " circle " ) is an opening at the opposite end of an animal \'s digestive tract from the mouth .',
#  'They have been part of the Duchy of Normandy since the tenth century , and Queen Elizabeth II is often referred to by her traditional and conventional title of Duke of Normandy .',
#  'Further mention of events in Kent occurs in the late sixth century history of the Franks by Gregory of Tours .',
#  'Essentialism is the most typically enacted philosophy in American classrooms today .',
#  'During this time , Jeanne Duval became his mistress .',
#  'It is also colloquially referred to as " the stans " as the countries generally considered to be within the region all have names ending with the Persian suffix " - stan " , meaning " land of " .',
#  "Utah 's governor , Gary Herbert , is also a church member .",
#  'This would show up in a larger number of possible mates for AMH humans , with increased risks of inbreeding amongst Neanderthal populations .',
#  '" Common Lisp " ( " CL " ) is a dialect of the Lisp programming language , published in ANSI standard document " ANSI INCITS 226 - 1994 ( R2004 ) " ( formerly " X3 .',
#  'In 1979 , the multi-platinum album " Discovery " was released , reaching number one on the UK Albums Chart .',
#  'It has acted as a crossroads for the movement of people , goods , and ideas between Europe , Western Asia , South Asia , and East Asia .',
#  "The Sheriff 's force , some of whom may have been intoxicated , traveled back to Manton to seize the remaining records .",
#  'The video was widely played on MTV .',
#  'He made his senior debut for Canada in a January 1986 friendly match against Paraguay and went on to earn 25 caps .',
#  'Upon joining the club he stated that he was expecting to play as a striker , rather than as a utility forward , though he admitted he faced a challenge in dislodging either of free-scoring duo Tom Pope and Lee Hughes .',
#  'Two projections of the Tian Shan create three " bays " along the eastern mountains .',
#  'The film tells the rags-to-riches story of a young street performer from the slums of Bombay .',
#  'Joss Whedon was credited as executive producer throughout the run of the series , and for the first five seasons ( 1997 – 2001 ) he was also the showrunner , supervising the writing and all aspects of production .',
#  'This aborted single mix can be heard on " The World Wo n\'t Listen " , while a remixed version is included in " Louder Than Bombs " .',
#  'He was buried in the Alley of Honor , in Baku .',
#  'The largest , in the north , is eastern Kazakhstan , traditionally called Jetysu or Semirechye which contains Lake Balkhash .',
#  'is a Maltese politician and a novelist .',
#  'The show was created and hosted by Marc Weiner .',
#  'The mongoose is itself preyed on by larger predators such as the African hawk-eagle .',
#  'She was formerly married to baseball player David Justice , singer-songwriter Eric Benét , and actor Olivier Martinez .',
#  'In the center is the small but densely-populated Ferghana valley .',
#  'While a primary concern has been the relationship between the writing process and natural places , concepts of spatiality also apply to cyberspace and online writing - in MUDs , MOOs , Internet Relay Chat , Instant Messages , and e-mail ( Syverson , 1999 ; Yagelski , 2002 ) .',
#  'In December 1983 , he became the first " big name " free agent to be signed by the Detroit Tigers .',
#  '" Americomics " was canceled after issue # 6 , and so far this story has never been referenced by any other publisher .',
#  'England were all out not long afterwards for 364 , a first innings lead of 121 .',
#  'The Syr Darya ( Jaxartes ) rises in the Ferghana valley and the Amu Darya ( Oxus ) rises in Bactria .',
#  'The last major outbreak in India occurred in 1998 .',
#  "He added a fourth goal to his season 's tally when he scored the winning goal in Walsall 's 1 – 0 victory over Chesterfield at the Bescot Stadium on 7 March 2017 .",
#  "She continues to engage in works that support her parents ' legacies and is on the board of directors of the Richard Nixon Foundation .",
#  'A director of the Bank of Montreal from 1864 to 1867 , he was a driving force behind the creation of the Canadian Bank of Commerce of which he served as the founding president from 1867 to his death in 1887 .',
#  'Both flow northwest into the Aral Sea .',
#  'According to trade papers , the film was a " notable box office attraction " at British cinemas in 1947 .',
#  'As a result , he was unable to play again in the series and Shakib Al Hasan took over .',
#  'The TVA Office of the Inspector General \'s report , " Inspection 2008 - 12283 - 02 , Review of the Kingston Fossil Plant Ash Spill Cause Study and Observations About Ash Management , " concluded that TVA culture had contributed to the spill .',
#  'Out of love for his wife , he subsequently converted to Catholicism .',
#  'Where the Oxus meets the Aral Sea it forms a large delta called Khwarazm and later the Khanate of Khiva .',
#  'The city is a major railroad terminal and the shipping center for north-eastern Argentina .',
#  'Nedelya Petkova created the first Bulgarian school for women in the city .',
#  'In 1983 , he was cast in the title role in " Sadat " , a miniseries which chronicled the life and assassination of Anwar Sadat .',
#  'Her parts were of a silent movie star in the 1920 s and a deaf librarian in the 1970 s ; in preparation , she studied sign language and watched the films of Lillian Gish .',
#  'The other great commercial city was Tashkent northwest of the mouth of the Ferghana valley .',
#  "With these and other weapons Russia for a long time has been among the world 's top suppliers of arms .",
#  'On 28 February 1999 , he scored his first international goal in the 2000 African Cup of Nations qualifier against Liberia which ended as 1 – 1 draw .',
#  'He began publishing articles in Henri Berr \'s " Revue de Synthèse Historique " .',
#  'His most successful album of this period was " Crises " ( 1983 ) , which features the worldwide hit single " Moonlight Shadow " with vocalist Maggie Reilly .',
#  'The land immediately north of the Oxus was called Transoxiana and also Sogdia , especially when referring to the Sogdian merchants who dominated the silk road trade .',
#  'As his behaviour becomes more erratic , Reggie is unable to dictate letters without uttering words like " breast " .',
#  'The level of destruction was extreme on the northwestern flank of the city in the areas immediately inland of the aquaculture ponds , and directly facing the Indian Ocean .',
#  'The term " khichdi " ( ) is derived from Sanskrit , a dish of rice and legumes .',
#  'In August 2020 , Halford confirmed that he had completed an audiobook version of the publication , to be made available at the same time as the physical release .',
#  'Margiana was the region around Merv .',
#  'After he left Oxford in 1923 , his cricket appearances became increasingly intermittent , and in 1932 , at the age of 31 , he gave up the first-class game altogether , although he played in occasional minor matches until 1947 .',
#  'The film was released on Blu-ray on April 3 , 2012 , and features all supplemental material from the DVD release .',
#  'He also held a research position at the Institute of Mathematics of the Romanian Academy , and was elected corresponding Member of the Romanian Academy in 1997 .',
#  'In the common , colloquial , vulgar or familiar register / sociolect , words of local origin or a mixture of local and Spanish words predominate .',
#  'In early times Buddhism spread north and throughout much of history warrior kings and tribes would move southeast to establish their rule in northern India .',
#  'Both songs later appeared on the " Building Nothing Out of Something " compilation and were left unreleased elsewhere .',
#  'To the east is the commercial and residential district of Merchant City .',
#  'In 1987 , he had an NCAA-record 58-game hitting streak , breaking the previous record of 47 ; he also led Division I in RBIs two years in a row .',
#  'Rome outgrew the Servian Wall , but no more walls were constructed until almost 700 years later , when , in 270 AD , Emperor Aurelian began building the Aurelian Walls .',
#  'Winters feature occasional rain and / or snow from low-pressure systems that cross the area from the Mediterranean Sea .',
#  'It takes its name from the Greek word for a rainbow , which is also the name for the Greek goddess of the rainbow , Iris .',
#  'After a loan spell the striker got back into the scoring way against Roma , on 26 February 2012 with a marvelous hat-trick and take his goal tally up to 15 for the season .',
#  'The team plays its home games at AT&T Field which opened in 2000 and seats 6,340 fans .',
#  'It is the first installment in the " Far Cry " series , followed by 2008 \'s " Far Cry 2 " .',
#  'The well-preserved Tarim mummies with Caucasoid features have been found in the Tarim Basin .',
#  'In the end , however , Chelsea won 2 – 1 .',
#  'There are , however , matrices for which the reverse Cuthill–McKee algorithm performs better .',
#  "A large group of artists , including Martin Scorsese and Alec Baldwin , and scholars signed a legal brief arguing the film 's artistic merit ; the Ohio state court dismissed the case because the police violated the owners ' Fourth Amendment rights , without reaching the question of whether the film was obscene .",
#  'Williamina Fleming classified most of the spectra in this catalogue and was credited with classifying over 10,000 featured stars and discovering 10 novae and more than 200 variable stars .',
#  'During the 13th and 14th centuries , the Mongols conquered and ruled the largest contiguous empire in recorded history .',
#  'This introduced him to Jules Laforgue , Arthur Rimbaud , and Paul Verlaine .',
#  'Peruvian midfielder Renato Tapia admitted to the speculation by saying that the Colombians approached them about the draw as they knew the results of the other games .',
#  'The main distribution of the subfamily is in tropical America , in tropical and Southern Africa , and in Australia .',
#  'The next settlement is on the bottom , in Whakapapa .',
#  'It is principally practiced in Kyrgyzstan and Kazakhstan by " akyns " , lyrical improvisationalists .',
#  "Allied and Russian forces were revived only briefly by Romania 's entry into the war on 27 August , as Romania was rapidly defeated by a Central Powers offensive .",
#  'On 31 August 2012 , Sint-Truiden came to an agreement with Standard Liège .',
#  'This took place at Cleveland Stadium on July 13 .',
#  'In June 1940 , the Soviet Union forcibly annexed Estonia , Latvia and Lithuania , and the disputed Romanian regions of Bessarabia , northern Bukovina and Hertza .',
#  'They are usually accompanied by a stringed instrument - in Kyrgyzstan , a three-stringed komuz , and in Kazakhstan , a similar two-stringed instrument , the dombra .',
#  'The lake lies in the municipalities of Røros ( in Trøndelag county ) and Os ( in Innlandet county ) .',
#  "The loss of Major League Baseball was part of a slow decline for NBC 's sports division .",
#  'He scored his fourth and fifth international goal against Tajikistan .',
#  'From 1959 , he was commander-in-chief of the forces in the Odessa Military District .',
#  'The first world title competition was played in 2017 and won by Kazakhstan .',
#  "He was also the TV voice of the New York Knicks ' only two championships , in 1970 and in 1973 .",
#  'Lee Baxter began the 1998 season as the first choice .',
#  'He is a former chairman of the Hong Kong branch of Royal Institution of Chartered Surveyors .',
#  'Avicine ( CTP-37 ) is a peptide fragment of Human chorionic gonadotropin ( hCG ) , an oncofoetal protein expressed by most cancer lines , the significant role of hCG being to ward off the immune system , the same way cells of the developing foetus ward off the immune system .',
#  'Between 2005 and 2013 , the share of agriculture dropped in all but Tajikistan , where it increased while industry decreased .',
#  'He managed the club until June 2014 , when he was hired as youth coach of Brøndby IF .',
#  'In 1951 they starred in a second film , " Chained for Life " , an exploitation film loosely based on their lives .',
#  'The constitution mandated a new election within sixty days , but owing to the crisis Hindenburg postponed it .',
#  "Mohamed Atta , Marwan al-Shehhi , Ziad Jarrah , Ramzi bin al-Shibh , and Said Bahaji were all members of al-Qaeda 's Hamburg cell .",
#  'The fastest growth in industry was observed in Turkmenistan , whereas the services sector progressed most in the other four countries .',
#  'Piranhas have also been discovered in the Kaptai Lake in southeast Bangladesh .',
#  'The theatre was named after its original owner , Paramount Pictures .',
#  'In 1889 some fifty thousand potential settlers gathered at the edges of the Unassigned Lands in hopes of staking a claim to a plot .',
#  'This weather pattern is frequently visible in summer across Canterbury and North Otago .',
#  'Kyrgyzstan has the added disadvantage of being considered resource poor , although it does have ample water .',
#  'Concurrently she launched CASH Music , a subscription-based , direct-to-consumer website , that was formed along with fellow musician Donita Sparks .',
#  'His replacement was Joe Gibbs .',
#  'Her father was from Glasgow , Scotland .',
#  'Like town planning , housing also followed the common pattern of other Harappan cities .',
#  'Bolstered by strong economic growth in all but Kyrgyzstan , national development strategies are fostering new high-tech industries , pooling resources and orienting the economy towards export markets .',
#  'In November 2009 he was a guest on " Private Passions " , the biographical music discussion programme on BBC Radio 3 .',
#  "Throughout Zapp 's history , around 15 musicians participated .",
#  'He was educated in Galatasaray High School and Istanbul Municipal Conservatory .',
#  'He resigned the premiership on 27 April 1909 , but was not relieved of his office until the formation of the Khuen-Héderváry cabinet on 17 January 1910 .',
#  'Turkmen , is mainly spoken in Turkmenistan , and as a minority language in Afghanistan , Russia , Iran and Turkey .',
#  "Despite the IAU 's declaration , a number of critics remain unconvinced .",
#  'Sheikh Abdullah went to Pakistan in the spring of 1964 .',
#  'Most Rodnover groups strongly emphasise the worship of ancestors .',
#  'Originally named as a species of " Polacanthus " .',
#  'Uzbek and Uyghur are spoken in Uzbekistan , Tajikistan , Kyrgyzstan , Afghanistan and Xinjiang .',
#  'He has also called football and basketball games for the Iowa Hawkeyes and the Michigan Wolverines .',
#  'He was cast and shared top billing with Barbra Streisand and Walter Matthau .',
#  'He provided narration for " Mishima : A Life in Four Chapters " ( 1985 ) .',
#  'He was instrumental in the design of the Ferranti Pegasus computer .',
#  'Korean is spoken by the Koryo-saram minority , mainly in Kazakhstan and Uzbekistan .',
#  '" Struthiomimus " ( meaning " ostrich mimic " , from the Greek στρούθειος / " stroutheios " meaning " of the ostrich " and μῖμος / " mimos " meaning " mimic " or " imitator " ) is a genus of ornithomimid dinosaurs from the late Cretaceous of North America .',
#  'His close friends included the philosopher and fellow émigré Isaiah Berlin and composer Igor Stravinsky .',
#  'He was called back up to the Dodgers on 9 June and remained with the club the rest of the season as a reserve outfielder .',
#  'With 90 minutes on the clock , the score was 2 – 2 and Bolton won 4 – 3 in extra time to end their 15-year exile from the top flight .',
#  'In Siberia , shaministic practices persist , including forms of divination such as Kumalak .',
#  "Therefore , the part of the customer 's IT budget available for hardware vendors would be significantly reduced in the coming years , and with it the base for IBM revenue .",
#  'Corresponding proteins are expressed in the different compartments of the adrenal gland , such as CYP11A1 , HSD3B2 and FDX1 involved in steroid hormone synthesis and expressed in cortical cell layers , and PNMT and DBH involved in noradrenaline and adrenaline synthesis and expressed in the medulla .',
#  "The well-known symbol of the city 's decades-long demise , the Michigan Central Station , was long vacant .",
#  'He also appeared in eight films produced by Hal B. Wallis and two with producer Mark Hellinger .',
#  'Clade E & F acantharians have a more specific symbiosis and primarily host symbionts from the haptophyte genus " Phaeocystis " , although they sometimes also host " Chrysochromulina " symbionts .',
#  'In particular , early Aboriginal people are thought to have been fire-stick farmers using fire regularly and persistently to drive game , open up dense thickets of vegetation , and create fresh green regrowth for both humans and game animals to eat .',
#  'To combat pathogens that replicate outside cells , antibodies bind to pathogens to link them together , causing them to IGL @ .',
#  'Major airports in the state are Visakhapatnam , Rajamahendravaram , Vijayawada , with Visakhapatnam , Tirupati and Vijayawada being international airports .',
#  'Fluoxetine was developed at Eli Lilly and Company in the early 1970 s by Bryan Molloy , Klaus Schmiegel , David T. Wong and others .',
#  'Clade F acantharians simultaneously host multiple species and strains of " Phaeocystis " and their internal symbiont community does not necessarily match the relative availability of potential symbionts in the surrounding environment .',
#  'Upset at the sight , he concluded : " Our Swansea is dead " .',
#  'The London exhibit was visited by over 300,000 people , making it one of the most successful exhibitions ever staged at the museum .',
#  'JAL operated the - 100BSR SUD with 563 seats on domestic routes until their retirement in the third quarter of 2006 .',
#  'In Ban Chiang , Thailand , ( Southeast Asia ) bronze artifacts have been discovered dating to 2100 BC .',
#  'Anarchists have taken part in several revolutions , most notably in the Spanish Civil War , whose end marked the end of the classical era of anarchism .',
#  'The EE brand , network and high street stores will be retained and will become a second consumer division , operating alongside BT Consumer .',
#  'Caithness , Sutherland and the Northern Isles have the densest concentrations , but there are a great many examples in the west of Scotland and the Hebrides .',
#  'Luxury DMU series 7021 , built in France , started to operate for Yugoslav Railways in 1972 and after 1991 stil remained in service of Croatian Railways until 2005 .',
#  'Lower Navarre became a province of France in 1620 .',
#  'Various factions within the French Revolution labelled their opponents as " anarchists " , although few such accused shared many views with later anarchists .',
#  'In Sri Lanka the title doctor " Dr. " is used for both physicians ( including dentists and veterinarians ) and Ph.D. holders .',
#  'For any group ( " G " , ∘ ) and any integer " n " ≥ 0 , repeated application of the direct product gives the group of all " n " - tuples " G " ( for " n " " = " 0 we get the trivial group ) , for example " Z " and " R " .',
#  'The city satisfied the Roman demands for eastern luxuries .',
#  'A 1940 s-era bronze statue depicting a classical nude woman was originally installed to overlook a reflecting pool in the Grosse Pointe War Memorial .',
#  'Many revolutionaries of the 19th century such as William Godwin ( 1756 – 1836 ) and Wilhelm Weitling ( 1808 – 1871 ) would contribute to the anarchist doctrines of the next generation , but they did not use " anarchist " or " anarchism " in describing themselves or their beliefs .',
#  'Director Wolfgang Petersen has overseen the creation of several different versions of his film .',
#  'Ecological systems theory , originally formulated by Urie Bronfenbrenner , specifies four types of nested environmental systems , with bi-directional influences within and between the systems .',
#  'The Persians then proceeded to besiege , capture and burn Eretria .',
#  'Adolf Hitler took a similar approach in some of his speeches from 1920 onwards .',
#  'The first political philosopher to call himself an " anarchist " ( ) was Pierre-Joseph Proudhon ( 1809 – 1865 ) , marking the formal birth of anarchism in the mid-19 th century .',
#  'The immediate reaction of the Southern military and public sectors was that Gettysburg was a setback , not a disaster .',
#  'Above these last three neighborhoods , on the western slopes of the Berkeley Hills are the neighborhoods of " Cragmont " and " La Loma Park " , notable for their dramatic views , winding streets , and numerous public stairways and paths .',
#  'He has also been praised for running good programs ( none of his teams was ever sanctioned by the NCAA for recruiting violations ) , and nearly all of his players graduated .',
#  'In the 2010 season , a new , larger model appeared in several colours representing different parts of the Dalek command hierarchy .',
#  'Most notable precursors to anarchism in the ancient world were in China and Greece .',
#  'On two separate but related occasions in 1925 , the con artist Victor Lustig " sold " the tower for scrap metal .',
#  'However , no coordinated attempt would be made to drive the Moors out .',
#  'These and other branches of engineering are represented in the 36 licensed member institutions of the UK Engineering Council .',
#  'In other words : the numbers , sometimes called Euler zigzag numbers , are integers .',
#  'In China , philosophical anarchism ( i.e. the discussion on the legitimacy of the state ) was delineated by Taoist philosophers Zhuang Zhou and Laozi .',
#  '" By August , Sun had released ten sides credited to " Elvis Presley , Scotty and Bill " ; on the latest recordings , the trio were joined by a drummer .',
#  "D'Abreu sailed through Ambon and Seram while his second in command Francisco Serrão went ahead towards the Maluku islands , was shipwrecked and ended up in Ternate .",
#  'Common non-alcoholic drinks include tea , the popularity of which was increased by Catherine of Braganza , and coffee ; frequently consumed alcoholic drinks include wine , ciders and English beers , such as bitter , mild , stout and brown ale .',
#  "Since the ending of the region 's conflict tourism has boomed in Northern Ireland , greatly aided by low cost .",
#  'Anarchic attitudes were also articulated by tragedians and philosophers in Greece .',
#  'In the early morning of 25 December 1977 , Chaplin died at home after suffering a stroke in his sleep .',
#  'Copenhagen is home to the University of Copenhagen , the Technical University of Denmark , Copenhagen Business School and the IT University of Copenhagen .',
#  'Copenhagen has several handball teams - a sport which is particularly popular in Denmark .',
#  'These are mainly preserved in sources such as graffiti and the Vindolanda tablets .',
#  'In Basra , religious sects preached against the state .',
#  'Many Mennonites immigrated from Pennsylvania and formed their own colonies .',
#  'Catholics , Eastern Christians , Lutherans , Anglicans and other traditional Protestant communities frame worship around the liturgical year .',
#  'These airports are located in the region of Annobón , Bata , Mongomoyen , and Corisco .',
#  'It borders the Gulf of Finland , between Latvia and Russia .',
#  'Libertarian ideas further emerged during the Renaissance with the spread of humanism , rationalism and reasoning through Europe .',
#  'The earliest unequivocal fossils of cartilaginous fishes first appeared in the fossil record by about 430 million years ago , during the middle Wenlock Epoch of the Silurian period .',
#  'Ericsson issued a profit warning in March 2001 .',
#  'In the non-USSR annexed portion of Poland , less than a third of Poland \'s population voted in favor of massive communist land reforms and industry nationalizations in a policies referendum known as " 3 times YES " ( " 3 razy TAK " ; " 3xTAK " ) , whereupon a second vote rigged election was held to get the desired result .',
#  'For example , the National Labor Relations Board issues relatively few regulations , but instead promulgates most of its substantive rules through common law ( connotation 1 ) .',
#  'During the French Revolution , partisan groups such as the Enragés and the saw a turning point in the fermentation of anti-state and federalist sentiments .',
#  'Europium was isolated in 1901 and is named after the continent of Europe .',
#  'Carloman resigned office in 746 , preferring to enter the church as a monk .',
#  'The state island stood in the Adriatic Sea near Italy .',
#  'In 1821 , he was appointed physician extraordinary to King George IV , and was also made mayor of Berkeley and justice of the peace .',
#  'This era of classical anarchism lasted until the end of the Spanish Civil War and is considered the golden age of anarchism .',
#  'Upon arrival , Rommel concurred with the plan .',
#  'Other science fiction series have similarly used word substitution to avoid censorship , such as " frell " instead of " fuck " in " Farscape " , " gorram " and " rutting " instead of " goddamn " and " fucking " in " Firefly " , and " frag " instead of " fuck " in " Babylon 5 " .',
#  'A selection of fifty aphorisms , focusing on the development of unrealized human talents through the creative process , appeared in the July 2005 issue of " Harper \'s Magazine " .',
#  'Extreme weather changes are common in Colorado , although a significant portion of the extreme weather occurs in the least populated areas of the state .',
#  'In China , small groups of students imported the humanistic pro-science version of anarcho-communism .',
#  'Clouds and drifting smoke resulted in a secondary target , Nagasaki , being bombed instead .',
#  'The survey also revealed 48 percent of Californians say religion is " very important " , compared to 56 percent nationally .',
#  'Sockeye salmon , Coho and Chinook ( also known as " king " ) salmon , and steelhead , all of the genus " Oncorhynchus " , are ocean fish that migrate up the rivers at the end of their life cycles to spawn .',
#  'Recognized sub-specialties in the United States by the ACGME are cardiac electrophysiology , echocardiography , interventional cardiology , and nuclear cardiology .',
#  'In the Spanish Civil War of 1936 , anarchists and syndicalists ( CNT and FAI ) once again allied themselves with various currents of leftists .',
#  'The southern savanna plain extends from the edge of the Adamaoua to Lake Chad .',
#  'By the time of emancipation , slaves outnumbered that of freemen on Grand Cayman .',
#  'They are accused of displacing 17,000 people in November 2016 and at least 30,000 people in the Ouham-Pendé prefecture in December 2016 .',
#  'Beneficiaries can also opt for more costly private insurance through Isapre .',
#  'The Soviet Union provided some limited assistance at the beginning of the war , but the result was a bitter fight among communists and anarchists at a series of events named May Days as Joseph Stalin tried to seize control of the Republicans .',
#  'In 1917 – 19 , Federico Tinoco Granados ruled as a dictator .',
#  'The film " Gattaca " ( 1997 ) provides a fictional example of a dystopian society that uses eugenics to decide what people are capable of and their place in the world .',
#  'A widespread network of state roads in Croatia acts as motorway feeder roads while connecting all major settlements in the country .',
#  'The longest rivers emptying into the Adriatic Sea are the Cetina and an only section of the Neretva .',
#  'At the end of World War II , the anarchist movement was severely weakened .',
#  'After it lost its subsidies from the USSR , Cuba withdrew its troops from Ethiopia ( 1989 ) , Nicaragua ( 1990 ) , Angola ( 1991 ) , and elsewhere .',
#  'This includes writers such as Stephanos Stephanides and Othello .',
#  'Another theme of the " Skylark " novels involves precursors of modern information technology .',
#  "MGM 's special edition of the 1981 film was not released until 2003 because the original negative had gone missing .",
#  'However , the 1960 s witnessed a revival of anarchism , likely caused by a perceived failure of Marxism–Leninism and tensions built by the Cold War .',
#  'Deep water vessels cannot manoeuvre ; in that sense , Elbląg has become a subsidiary port of Gdańsk .',
#  'Constitutional monarchies range from countries such as Liechtenstein , Monaco , Morocco , Jordan , Kuwait and Bahrain , where the constitution grants substantial discretionary powers to the sovereign , to countries such as the United Kingdom , Spain , Belgium , Sweden and Japan , where the monarch retains significantly less personal discretion in the exercise of their authority .',
#  'Their first defeat on home soil to a foreign team was a 2 – 0 loss to Ireland , on 21 September 1949 at Goodison Park .',
#  'An example of an important endoplasmic reticulum resident protein is the chaperone protein known as BiP which identifies other proteins that have been improperly built or processed and keeps them from being sent to their final destinations .',
#  'During this time , anarchism took root in other movements critical towards both capitalism and the state such as the anti-nuclear , environmental and peace movements , the counterculture of the 1960 s and the New Left .',
#  "Each participating country submits an original song to be performed on live television and radio , transmitted to national broadcasters via the EBU 's Eurovision and Euroradio networks , with competing countries then casting votes for the other countries ' songs to determine a winner .",
#  'William requested of the king that he take care of both the lands and the duchess , and find her a suitable husband .',
#  'In 2001 and 2002 , several riots broke out at Sangatte , and groups of migrants ( up to 550 in a December 2001 incident ) stormed the fences and attempted to enter " en masse " .',
#  'It was written by the Icelandic scholar and historian Snorri Sturluson around 1220 .',
#  'Anarchism became associated with punk subculture as exemplified by bands such as Crass and the Sex Pistols .',
#  'Soon after , Tony Hoare gave the problem its present formulation .',
#  'In the 2000 s , the liberal Ciudadanos and leftist party Podemos became part of the political context , gaining electoral consensus , followed years later by conservative party Vox .',
#  'All locks on the New York State Canal System are single-chamber ; the dimensions are long and wide with a minimum depth of water over the miter sills at the upstream gates upon lift .',
#  '" Chinese numerals " are words and characters used to denote numbers in Chinese .',
#  'A significant event of this period was the confrontations at the 1999 Seattle WTO conference .',
#  'While " Tiān " has some characteristics that overlap the category of godhead , it is primarily an " impersonal " absolute principle , like the " Dào " ( ) or the " Brahman " .',
#  "Confucius 's disciples and his only grandson , Zisi , continued his philosophical school after his death .",
#  'John Locke is sometimes considered the founder of this form .',
#  'Colombia subsequently withdrew some of its reservations , most notably a reservation on extradition .',
#  'One reaction against sectarianism within the anarchist milieu was anarchism without adjectives , a call for toleration and unity among anarchists first adopted by Fernando Tarrida del Mármol in 1889 in response to the bitter debates of anarchist theory at the time .',
#  'The main catalyst for its transformation from a small town into a big city was the demand for coal required in making iron and later steel , brought to the sea by packhorse from Merthyr Tydfil .',
#  'Among non-governmental organizations ( NGOs ) , Amnesty International and Human Rights Watch are noted for their opposition to capital punishment .',
#  'Other Orthodox communities can identify with two Eastern Orthodox churches simultaneously , for example Caucasus Greeks and Pontic Greeks in Russia often identify with both the Greek Orthodox Church and Russian Orthodox Church , as a result of centuries of assimilation and intermarriage with ethnic Russians and other Christian Orthodox communities in mainly southern Russia .',
#  'The World Clown Association is a worldwide organization for clowns , jugglers , magicians , and face painters .',
#  'Mutualism is an 18th - century economic theory that was developed into anarchist theory by Pierre-Joseph Proudhon .',
#  'The Kebaran culture , with its use of microliths , is associated also with the use of the bow and arrow and the domestication of the dog .',
#  'The Cleveland Marathon has been hosted annually since 1978 .',
#  "On 24 February , the Emperor 's state funeral was held , and unlike that of his predecessor , it was formal but not conducted in a strictly Shinto manner .",
#  'One condition normally taken into account in such a decision is the level of foreign ownership ; federal regulations require that Canadian citizens ultimately own a majority of a broadcast licence .',
#  'Collectivist anarchism is a revolutionary socialist form of anarchism commonly associated with Mikhail Bakunin .',
#  'The " Sonderkommando " talked to the victims about life in the camp to pacify the suspicious ones , and hurried them inside ; to that effect , they also assisted the aged and the very young in undressing .',
#  "Volunteers from the GPO also occupied other buildings on the street , including buildings overlooking O'Connell Bridge .",
#  'He came from a wealthy municipal family of the Roman equestrian order , and served as consul in 63 " BC .',
#  'Faith healing or divine healing is considered to be an inheritance of Jesus acquired by his death and resurrection .',
#  'Collectivist anarchism arose alongside Marxism , but it rejected the dictatorship of the proletariat despite the stated Marxist goal of a collectivist stateless society .',
#  'Many allege he is the wealthiest and most powerful man in the republic , with control over a large private militia referred to as the " Kadyrovtsy " .',
#  'Nursing studies emotions as part of its approach to the provision of holistic health care to humans .',
#  'His father was Emperor Kōgon .',
#  'The genealogical trees of the " Nihon Shoki " have been lost , and the accuracy of its account of events remains unknown .',
#  'Early influences on individualist forms of anarchism include William Godwin , Max Stirner and Henry David Thoreau .',
#  'Context-sensitive is one of the four types of grammars in the Chomsky hierarchy .',
#  'The economic impact of Christmas has grown steadily over the past few centuries in many regions of the world .',
#  'In the mathematical field of graph theory , a " cuboctahedral graph " is the graph of vertices and edges of the cuboctahedron , one of the Archimedean solids .',
#  "Initially , WKCR was n't a radio station , but an organization concerned with the technology of radio communications .",
#  'Not only did they confront state armed forces ( as in Spain and Ukraine ) but some of them also employed terrorism as propaganda of the deed .',
#  'The Vredeford Dome in the center of the Witwatersrand Basin is the largest goldfield in the world which has supplied about 40 % of all the gold ever mined in an impact structure ( though the gold did not come from the bolide ) .',
#  'In science fiction , " Camouflage " is a novel about shapeshifting alien beings by Joe Haldeman .',
#  'Branwell may have had a laudanum addiction .',
#  'When his reforms were blocked by a financial official about to become a judge for life , Hannibal rallied the populace against the 104 judges .',
#  'Emma Goldman and Errico Malatesta , who were proponents of limited use of violence , argued that violence is merely a reaction to state violence as a necessary evil .',
#  'Consequently , these schools hold that Muslims must perform " wudhu " ( ablution ) before the next time they pray after eating camel meat .',
#  'This portal lands them in AD 2300 , where they learn that an advanced civilization has been wiped out by a giant creature known as Lavos that appeared in 1999 .',
#  'Other high-performance vendors like Control Data Corporation implemented similar designs .',
#  "Many of the city 's suburbs lie on the large plain called the Cape Flats , which extends over to the east and joins the peninsula to the mainland .",
#  'They mostly engage in confronting the police during demonstrations and riots , especially in countries such as Canada , Greece and Mexico .',
#  'Through the late 1890 s and early 1900 s ( decade ) , the Reds moved to two different parks where they stayed for less than ten years .',
#  "The exact formula of Coca-Cola 's natural flavorings ( but not its other ingredients , which are listed on the side of the bottle or can ) is a trade secret .",
#  "With the extermination of the wolf , the coyote 's range expanded to encompass broken forests from the tropics of Guatemala and the northern slope of Alaska .",
#  'Ceanothus velutinus " is the most common member of this genus and is widespread through much of western North America .',
#  'In contrast with the " big-A anarchism " of the classical era , the newly coined term " small-a anarchism " signals their tendency not to base their thoughts and actions on classical-era anarchism or to refer to classical anarchists such as Peter Kropotkin and Pierre-Joseph Proudhon to justify their opinions .',
#  'He served as a local councillor and was Mayor of Wolverhampton in 1866 .',
#  'On November 11 , he was released after the team re-signed running back Aveion Cason .',
#  'Academically oriented gymnasiums have higher entrance requirements and specifically prepare for Abitur and tertiary education .',
#  "Organizations such as the cause célèbre became popular among the city 's African-American youth .",
#  'Similarly , anarchism enjoys complex relationships with ideologies such as communism , collectivism , Marxism and trade unionism .',
#  'In 1835 Chopin went to Carlsbad , where he spent time with his parents ; it was the last time he would see them .',
#  'Today , along with the Wachusett Reservoir , it is the primary water supply for Boston , some to the east as well as 40 other communities in Greater Boston .',
#  'The local government area is in size , about 2 % of the area of Wales .',
#  "He then entered the service of Sir Augustine Nicolls , a relative of his mother 's , as a clerk .",
#  "Late 20th century and contemporary anarchist writers ( Colin Ward , Herbert Read and Paul Goodman ) intensified and expanded the anarchist critique of state education , largely focusing on the need for a system that focuses on children 's creativity rather than on their ability to attain a career or participate in consumerism as part of a consumer society .",
#  'Titus Oates was convicted and imprisoned for defamation .',
#  'Due to budget limitations the crew was composed essentially of Italians , none of whom spoke English .',
#  'He bestowed the George Cross on the entire " island fortress of Malta " in 1943 .',
#  "Most of Quebec 's English-speaking population resides in the Montreal region on the Island of Montreal .",
#  'Anarchists such as Leo Tolstoy and Herbert Read argued that the border between the artist and the non-artist , what separates art from a daily act , is a construct produced by the alienation caused by capitalism and it prevents humans from living a joyful life .',
#  'The county town was Clonmel ; other important urban centres included Carrick-on-Suir , Cashel , Cahir and Tipperary .',
#  "Still , Roberto 's career was ultimately cut short by injury .",
#  'It is also a Mars - and Venus-crosser asteroid .',
#  'Survivors of the second , after contact with Australian troops , also made it back to Indonesia .',
#  'Throughout the 20th century , many prominent anarchists ( Peter Kropotkin , Emma Goldman , Gustav Landauer and Camillo Berneri ) and publications such as " Anarchy " wrote about matters pertaining to the arts .',
#  'On 7 April 1911 he was sworn to secrecy by the Irish Republican Brotherhood .',
#  'In May 1963 , he published a book devoted to poet , novelist , and playwright Raymond Roussel .',
#  'The city bills itself as The Entertainment Capital of the World , and is famous for its mega casino-hotels and associated activities .',
#  'When he was discharged in January 1934 , he returned to Southwold to convalesce and , supported by his parents , never returned to teaching .',
#  'Philosopher Bertrand Russell supported this critique , noting that " [ p ] eace and war , tariffs , regulations of sanitary conditions and the sale of noxious drugs , the preservation of a just system of distribution : these , among others , are functions which could hardly be performed in a community in which there was no central government " .',
#  'He played two years of college soccer at UCLA .',
#  '1949 ) , Jeb ( b .',
#  "The philosophy of David Hume concerning causality and objectivity is an elaboration of another aspect of Berkeley 's philosophy .",
# ...
#  'Other notable buildings in the park include Cumberland Lodge , built in 1652 during the Commonwealth .',
#  'Up until World War I some armies made artillery responsible for all forward ammunition supply because the load of small arms ammunition was trivial compared to artillery .',
#  'Subsequent groups of immigrants have included Germans , Poles and Ukrainians .',
#  'He holds both a Ghanaian passport and a Turkish passport .',
#  'Most survivors and bodies were washed out into the Everglades , where many of the bodies were never found .',
#  'Contemporary mutualist Kevin Carson holds that capitalism has been founded on " an act of robbery as massive as feudalism " and argues that capitalism could not exist in the absence of a state .',
#  'However , the general switch by artillery to indirect fire before and during World War I led to a reaction in some armies .',
#  'In November 1898 , he attained legal adulthood and , just eight months later , became heir presumptive to Nicholas as the middle brother , George , was killed in a motorcycle accident .',
#  '" Stronghold Kingdoms " is the first MMO-style game developed in the Stronghold series .',
#  "He was elected as the club 's new captain after the departure of former skipper Gregg Berhalter .",
#  'It was the site of the 1937 LZ 129 Hindenburg airship disaster .',
#  'In World War II they were joined by self-propelled assault guns , although other armies adopted infantry or close support tanks in armoured branch units for the same purpose , subsequently tanks generally took on the accompanying role .',
#  'She worked for several years as a field researcher , eventually earning her doctorate in biology from the University of Michigan .',
#  'An attempt in 18th - century style to explain the French Revolution , it predated his subsequent , romantic style of writing and was largely ignored .',
#  'She & Him \'s second Christmas album and sixth album overall , " Christmas Party " , was released in 2016 .',
#  'Deregistration is only practiced in country and suburban football competitions ; it is not practiced by the AFL as of 2019 , as the deregistration policy was designed for serial aggressive offenders , not low-level repeat offenders .',
#  'Towing by horse teams lasted throughout World War II in some armies , but others were fully mechanized with wheeled or tracked gun towing vehicles by the outbreak of that war .',
#  "Similarly , the treaty of Mangalore was signed in 1784 bringing hostilities with the British to a temporary and uneasy halt and restoring the others ' lands to the status quo ante bellum .",
#  'As an end , he was quickly able to fill the void in the offense left by the departure of two-time All-American Gaynell Tinsley .',
#  "At the 1956 Winter Olympics in Cortina d'Ampezzo , he won silver medals in the 2-man and 4-man bobsled events .",
#  'After about 1890 his mental and physical health began to fail , and he sought a warmer , drier climate for recovery ; he died in a hotel in Cairo , Egypt at the age of 64 , only ten months after his final concert performance .',
#  'SPs first appeared during World War I , but did not really develop until World War II .',
#  'The arena has a capacity for 5,145 spectators and was built in 1984 to host handball events at the 1988 Summer Olympics .',
#  'The canal was to be built as a narrow canal , but in 1775 , nine shareholders offered to fund the extra cost of making it a broad canal from Retford to Stockwith .',
#  'Late in the campaign , he suffered a hyper-extended knee during a game against the Edmonton Oilers on April 12 , 1999 .',
#  'Tiberius , now free of Livia , loses all compunction and executes hundreds of influential citizens on false charges of treason .',
#  'It appears to have been introduced in World War I , which spawned a very wide array of artillery in all sorts of sizes so a simple categorical system was needed .',
#  'He continued his career as a backup catcher with the Montreal Expos in , the St. Louis Cardinals in , and the minor league Buffalo Bisons in .',
#  'She defeated Belgian woman Elise Mertens in a third set tiebreak ( after three hours of play ) to set up a second round match with her sister Serena .',
#  'Parts of the video shot with Drake were filmed on October 27 , 2010 .',
#  'The following month , he signed for two years with fellow league side RCD Mallorca with an option for a further season .',
#  "Modern counter-battery fire developed in World War I , with the objective of defeating the enemy 's artillery .",
#  'He was the fraternal twin of Robin Gibb , and was the younger of the two by 35 minutes .',
#  'Hurricane preparedness for New Orleans was judged poor .',
#  'By 1892 he was involved in the Scottish Socialist Federation , acting as its secretary from 1895 .',
#  'The Jamaican coney is generally about the size of a cottontail rabbit , and mature adults usually weigh between 1 and 2 " kg .',
#  'In World War I the latter required air observation .',
#  'At Guangzhou , she was awarded a wildcard to the main draw , and proved she deserved it by advancing to the semi-final with easy straight-sets victories over Anikó Kapros , Nicole Pratt and ( most impressively of all ) Peng Shuai , only to lose again to her former long-time doubles partner ( and the eventual tournament champion ) Li Na .',
#  "However , after losing co-captain Shawn Redhage to a season-ending hip injury on January 23 , Brown 's contract was extended by the Wildcats to see out the 2010 – 11 season .",
#  'On 22 May 2015 , the FARC suspended a truce after 26 of its fighters were killed in a government air and ground offensive .',
#  'The main natural sources of food of " P. terribilis " are the ants in the genera " Brachymyrmex " and " Paratrechina " , but many kinds of insects and other small invertebrates can be eaten , specifically termites and beetles , which can easily be found on the rainforest floor .',
#  'Since December 1944 ( Battle of the Bulge ) , proximity fuzed artillery shells have been available that take the guesswork out of this process .',
#  'Bassist Nicky Wire said that was the moment he knew that the band had " made it " .',
#  'He also spent one season at Martigues , before retiring in 2002 .',
#  'Rights for some of the books have been sold to Taiwan .',
#  'Anything " , was released as a third single to little success .',
#  "Alabama 's capital is Montgomery .",
#  'Alexander uses this opportunity to rule in his own right - he becomes neither a pawn of his mother nor his father .',
#  'Despite its positive critical reception , the game sold one-third as many copies as its predecessor " Rise of Nations " .',
#  'His secondary education was undertaken at the independent Clifton College in Bristol .',
#  'CAT-iq allows any DECT handset to communicate with a DECT base from a different vendor , providing full interoperability .',
#  'The largest city by population is Birmingham , which has long been the most industrialized city ; the largest city by land area is Huntsville .',
#  'Ballpoints have also been produced to commemorate events , such as a pen commemorating the 1963 assassination of President John F. Kennedy .',
#  'In modern times , Turoyo ( see below ) has sometimes been written in a Latin script .',
#  'Modern Eastern Aramaic exists in a wide variety of dialects and languages .',
#  'The syntax of Aramaic ( the way sentences are put together ) usually follows the order verb–subject–object ( VSO ) .',
#  'From the American Civil War until World War II , Alabama , like many states in the southern U.S. , suffered economic hardship , in part because of its continued dependence on agriculture .',
#  'Soon after , the band \'s name was revised to " Bill Haley & His Comets " .',
#  'Chemical properties of americium were first studied with Am , but later shifted to Am , which is almost 20 times less radioactive .',
#  'The first of their two children , Rebecca , was born September 15 , 1962 .',
#  'A DoD study conducted at the behest of Secretary of Defense Robert Gates in 2010 supports this most .',
#  "Following World War II , Alabama grew as the state 's economy changed from one primarily based on agriculture to one with diversified interests .",
#  'It was selected for preservation in the United States Roger Ebert .',
#  'As a dentist , he was the main founder of the dentistry faculty of the Universidad de Chile , and he was eventually elected as the first dean .',
#  'Lapis lazuli pigment was also used to create the rich blues in Persian miniatures .',
#  'The opera was banned by the Nazis in 1933 and did not have a significant production until the 1960 s .',
#  'Some scholars suggest the word comes from the Choctaw " alba " ( meaning " plants " or " weeds " ) and " amo " ( meaning " to cut " , " to trim " , or " to gather " ) .',
#  'Aside from " kumi-daiko " performance , a number of folk traditions that use taiko have been recognized in different regions in Japan .',
#  'These are referred to by a number of ancient authors , including Pausanius ( III , 16 : 10 - 11 ) .',
#  'The skeleton below is compatible with the Bourne shell and gives semantics similar to csh for the and .',
#  'She returned to number one on the country chart later in 2005 by lending her distinctive harmonies to the Brad Paisley ballad , " When I Get Where I \'m Going " .',
#  'The meaning may have been " clearers of the thicket " referring to clearing land for cultivation However , there are no correspondingly similar words in the Alabama language .',
#  'The Doppler effect for electromagnetic waves such as light is of great use in astronomy and results in either a so-called redshift or blueshift .',
#  'Most territories around his kingdom were ruled by his relatives , who were descendants of either Timur or Genghis Khan , and were constantly in conflict .',
#  'However its nearest large city is Almaty of Kazakhstan , which is 190 " km to the east .',
#  'Other early examples include George Lucas \'s first two films being re-released following the success of " Star Wars " , in cuts which more closely resembled his vision , or Peter Bogdanovich re-cutting " The Last Picture Show " several times .',
#  'The expedition of Hernando de Soto passed through Mabila and other parts of the state in 1540 .',
#  'This expanded engine capacity allowed the entry-level V8 Vantage sports car to enter production at the Gaydon factory in 2006 , joining the DB9 and DB9 Volante .',
#  'In 2018 , he narrowly escaped a suicide bombing by ISIL-KP as he returned to Afghanistan at Kabul airport .',
#  'In December 2004 , the Supreme Court lifted a stay , thereby allowing the Brazil-based União do Vegetal ( UDV ) church to use a decoction containing DMT in their Christmas services that year .',
#  'The largest city and commercial hub of the state , Visakhapatnam being the executive capital while Amaravati and Kurnool serve as legislative and judicial capitals respectively .',
#  'The city was moved to the current site of Mobile in 1711 .',
#  'The props she may brandish will strongly signify her role as dominatrix , such as bearing a flogger , whip or riding crop as illustrated in the artwork of Bruno Zach in the early 20th century , in conventional representation .',
#  'By article 48 of its Constitution , Azerbaijan is a secular state and ensures religious freedom .',
#  "In the civic hospital , the deaconesses on duty were gradually replaced by National Socialist People 's Welfare nurses .",
#  'According to Livy ( vi .',
#  'He settled in the Tombigbee District during the early 1770 s .',
#  'During the Portuguese Colonial War in the 1960 s and the 1970 s , the Portuguese Army created an experimental horse platoon , to combat the guerrillas in eastern Angola .',
#  'The trade with Africa offered several possibilities to set up trading posts or factories , an important starting point for negotiations .',
#  'A virus with a novel method of genome packing infecting species of the genus " Sulfolobus " has been described .',
#  'It was followed by the studio album " Mirrors " ( 1979 ) .',
#  'Cahaba , now a ghost town , was the first permanent state capital from 1820 to 1825 .',
#  'Before World War II , destroyers were light vessels with little endurance for unattended ocean operations ; typically a number of destroyers and a single destroyer tender operated together .',
#  'Pete Rose has claimed that he applied for reinstatement over the years and received no such consideration .',
#  'Baryons are strongly interacting fermions ; that is , they are acted on by the strong nuclear force and are described by Fermi–Dirac statistics , which apply to all particles obeying the Pauli exclusion principle .',
#  'The ATI acquisition in 2006 included the Xilleon and Qualcomm product lines .',
#  'The Alabama Fever land rush was underway when the state was admitted to the Union , with settlers and land speculators pouring into the state to take advantage of fertile land suitable for cotton cultivation .',
#  'IDEA operates on 64-bit blocks using a 128-bit key , and consists of a series of eight identical transformations ( a " round " ) and an output transformation ( the " half-round " ) .',
#  'In Australian rules terminology , these players wait for substitution " on the bench " - an area with a row of seats on the sideline .',
#  "Commander Vice-Admiral François-Paul Brueys d'Aigalliers believed that he had established a formidable defensive position .",
#  'The result was a complex mixture of new wave and world music , in places incorporating Hijaz non-Western scales .',
#  "From 1826 to 1846 , Tuscaloosa served as Alabama 's capital .",
#  'Clement of Alexandria and some scholars have ascribed the Epistle of Barnabas to him , but his authorship is disputed .',
#  'The small island of Tabarca , 8 nautical miles to the south of the city , also belongs to the municipality .',
#  'They were defeated in five games by their opening round opponent , the Nashville Predators .',
#  'In October 2010 , she appeared on BBC One \'s " Strictly Come Dancing " , partnered by Anton du Beke , winning the support of some viewers despite low marks from the judges .',
#  'On January 30 , 1846 , the Alabama legislature announced it had voted to move the capital city from Tuscaloosa to Montgomery .',
#  'He also made generous donations of " jagirs " to many temples to gain the goodwill of his Hindu subjects .',
#  'A young boy discovered a small cache of ransom bills along the banks of the Columbia River in February 1980 .',
#  'Barker states that some knights , encumbered by their armour , actually drowned in their helmets .',
#  'The mid-to-late 19th century witnessed an increase in popularity of political Catholicism across Europe .',
#  'A new capitol building was erected under the direction of Stephen Decatur Button of Philadelphia .',
#  'In 1922 , he moved to Paris to study under the sculptor Antoine Bourdelle , an associate of Rodin .',
#  '" Hymn to Liberty " is the longest national anthem in the world by length of text .',
#  'The " BBC News at Ten " began simulcasting on the channel on 30 January 2006 as part of the " Ten O\'Clock Newshour " , followed by extended sport and business news updates .',
#  'Subsequently , he was a key member of the performers in the BBC radio series " I \'m Sorry , I \'ll Read That Again " , where many of his musical compositions were featured .',
#  'This second capitol building in Montgomery remains to the present day .',
#  'In 1992 , the company acquired de Havilland Canada from Boeing .',
#  'Another important performer in this period , Bertram Turetzky , commissioned and premiered more than 300 double bass works .',
#  'In 1885 , anatomist Walther Flemming delivered a more precise description of the process of programmed cell death .',
#  'Aarau was founded around AD 1240 by the counts of Kyburg .',
#  'On January 11 , 1861 , Alabama declared its secession from the Union .',
#  'On 12 June 2019 , it was announced CAF have been successful in their bid and have been awarded the contract to provide the new trains , entering service in 2023 .',
#  ...]

# %%
tags = []
for i in datasets["train_en"]:
    tags.append(i['ner_tags'])

# %%
for i in tags:
  for j in range (len(i)):

    if str(i[j]) == '0':
      i[j] = 'O'
    if str(i[j]) == '1':
      i[j] = 'B-per'
    if str(i[j]) == '2':
      i[j] = 'I-per'
    if str(i[j]) == '3':
      i[j] = 'B-org'
    if str(i[j]) == '4':
      i[j] = 'I-org'
    if str(i[j]) == '5':
      i[j] = 'B-geo'
    if str(i[j]) == '6':
      i[j] = 'I-geo'
    if str(i[j]) == '7':
      i[j] = 'B-misc'
    if str(i[j]) == '8':
      i[j] = 'I-misc'
  #print(i)

# %%
tags2 =[]
for i in tags:
  j = ' '.join(i)
  b = ' '.join(str(j).split(','))
  tags2.append(b)

# %%
tags2
# Out:
# ['O O O O O B-geo I-geo O O O O B-geo O O',
#  'O O O O O O B-org O O O O B-misc I-misc O O B-misc I-misc O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-geo O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-misc O O O O O O O O',
#  'O O O O B-per I-per O O O O B-per I-per O O O O O B-per I-per O O O O O O O O O O',
#  'O O O B-geo O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-org O O O',
#  'O O O O B-geo O O O O O O O O O O O B-geo O B-geo O O O O O',
#  'O O O O O O O O O O O O B-geo O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O O',
#  'O O O O O O B-geo O O O O O O O O O O O B-geo O',
#  'O O O O O O B-geo O O O O O O B-geo I-geo O B-geo O B-geo O B-geo O B-geo O B-geo O O B-geo I-geo O B-geo I-geo I-geo I-geo O O O O B-geo I-geo O O B-geo I-geo O O O O O O O O O O B-geo I-geo O B-geo O O B-geo O B-geo O O B-geo I-geo O O B-geo O',
#  'O O O O O O O O O O O O O B-misc O O O B-misc O O O B-misc O O',
#  'O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-per I-per O O O O O O I-misc O O O B-per I-per O O O I-misc O O O',
#  'O O O O O O O O B-per O',
#  'O B-misc O B-misc O O O O O O O',
#  'O O O O O O O O O O O B-misc O O O O O',
#  'O O O B-org O O O O O',
#  'O O O O O O O O O B-misc O O O O O O',
#  'O O O O O O O O O O O B-org O O O O O O O O O',
#  'O O O B-per O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O',
#  'O O O O O O O O B-org O O O O O',
#  'O O O B-geo I-geo O O O O O O',
#  'O O O O B-per I-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'B-org O O O O O O',
#  'O O O O O O O B-misc O B-misc O',
#  'O O O O O O O B-geo I-geo O O O O B-geo O B-geo I-geo O',
#  'O O O O O O O O O O O B-misc O O O O O O O O O',
#  'O O O O O O O B-geo O B-geo O O B-geo I-geo O O O O O O O B-geo I-geo I-geo I-geo O O O B-geo I-geo I-geo O O O B-geo O O O',
#  'O O O B-misc O O O O O O O O O O O O O O O O O O B-misc O O O B-geo O O O O B-geo O O O O',
#  'O O O B-org I-org O O O O O O O O O O O B-org I-org O O O O O O',
#  'B-geo O O O O O O O O O O O O O O',
#  'O O O O O O B-geo O O O O O O O O B-geo O O O O O O O',
#  'O O O B-per O O O O O O O',
#  'O O B-org I-org I-org O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-org I-org O O O O O O O O O O O O O O O O O O O O O O B-org I-org O',
#  'O O O O O O O O B-geo I-geo O',
#  'O B-misc O O O O O O O O O O O O O O O O O O O B-misc B-misc O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-geo O O O O O O O O',
#  'O O O O O B-geo I-geo O O O O O O O B-misc O O',
#  'O O O O O O B-org I-org O B-org O O O O O O O O',
#  'O O O O O O O O O B-misc O O O O O O O',
#  'O O O O B-misc I-misc I-misc I-misc O O O O O O O O O O O O O O O',
#  'O O O O B-geo O O O O O O O O O O O O O O O O O O O O',
#  'B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-org O B-org O B-org O',
#  'O O O O O O O O O O O B-geo O',
#  'O O O B-geo O O O O O O O O B-geo O O O O O O O O',
#  'O O O O O O O B-geo O O B-geo O O B-misc O O O B-misc O O O O B-misc O',
#  'O O O O O O O O O O O O O O B-per O',
#  'O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo I-geo I-geo O O O O O O O B-per I-per O O O O O O O O O O O O O B-geo O',
#  'O O O O O B-geo O O O O O O O O O B-misc O B-per I-per I-per O',
#  'O O O O O O O O B-misc O O O',
#  'O O O O B-per I-per O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O',
#  'B-geo O O O B-per I-per O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O B-misc O O',
#  'O B-misc B-misc O O O O O O O O O O O I-misc O O O O O B-org O O O B-org O O O O O O O O O O O O O',
#  'O O O O O O O B-misc O O O O O O O O O B-misc I-misc I-misc O',
#  'O O O O O O O O O O O O O O O O O B-geo O B-geo I-geo O B-geo I-geo O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O O B-geo O O O O O O',
#  'O O O O O O B-org O',
#  'O O O O O O B-geo O O O O O O O B-org O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per O B-per I-per O',
#  'O O O O B-geo I-geo O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-geo O',
#  'B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-misc I-misc I-misc I-misc I-misc O O O O O O O O O O B-misc I-misc I-misc O O',
#  'O O O O O B-geo I-geo I-geo O O B-geo O',
#  'O O O O O O O O O B-geo O O O B-geo O B-geo O O B-geo I-geo O',
#  'O O B-misc O O O O O',
#  'O O O O O O O B-per I-per O',
#  'O O O O O O O O O O O O B-misc O O',
#  'O O O O O O O B-per I-per O O B-per I-per O O O B-per I-per O',
#  'O O O O O O O O B-geo O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O I-misc I-misc I-misc O I-misc I-misc O O O O B-per O O O B-per O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-org I-org O',
#  'O B-misc O O O O O O O O O O O O O O O O O O O O O O',
#  'B-geo O O O O O O O O O O O O O O O O',
#  'O B-geo I-geo O B-geo O O O O B-geo O O O B-geo I-geo O B-geo O O O B-geo O',
#  'O O O O O B-geo O O O O',
#  'O O O O O O O O O O O O O O O O O B-org O O O O O O B-org O O B-geo I-geo O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O B-org I-org I-org O',
#  'O O O O B-org I-org I-org O O O O O O O O O O O O O O O B-org I-org I-org I-org O O O O O O O O O O O O O O O O',
#  'O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O O B-misc O O O O',
#  'O O O O O O O O O O O O O O B-per I-per I-per O O O',
#  'O B-org O O O O O O O O O O O O O O O O I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O O B-org O O O O O O O',
#  'O O O O O O O O O O O B-misc O',
#  'O O B-geo O O B-geo I-geo O O O O O O B-geo O O O B-geo I-geo I-geo O',
#  'O O O O O O O O O O O O O B-geo O',
#  'B-per I-per O O O B-misc O O O O O O O',
#  'O O O O O O O O O O O O B-misc O O O O O O O O O O O B-per I-per O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O O B-geo O O O O O O B-geo O O',
#  'O O O O O B-geo O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-misc I-misc I-misc I-misc I-misc O O B-geo O O O O O O O O',
#  'O O O O O B-per I-per O O I-misc I-misc I-misc I-misc O O',
#  'O O O O O O O O O B-misc O O O O O O O O O O O O I-misc I-misc O O O B-per I-per O',
#  'O O O O O O B-geo O O B-geo O O B-geo O O O O O O B-geo O O O O O O O O',
#  'O O O O O O O B-per O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O B-misc O O O O O O O O',
#  'O O O O B-per O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'B-geo O O O O B-geo O',
#  'O O O B-org O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-misc O O',
#  'O O O O O O O O B-org I-org I-org I-org I-org I-org I-org O O O O O O O O B-org I-org O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O',
#  'O O O B-misc O O O O O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O B-misc I-misc I-misc I-misc I-misc O O O O O O O O',
#  'O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O B-org I-org O O O O O O O O',
#  'O O O B-geo I-geo O O O O O O O O O O O O O O O O O O O O B-per O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O B-misc O O O O O O O O O O O O B-misc O O O O O B-per O',
#  'O O O O O O O O O O O O O B-org O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-geo I-geo O O O O O O O O O',
#  'O O O O O O O O I-misc I-misc O O O O O O O O B-misc I-misc I-misc O O',
#  'O O B-geo O O B-geo O O O O O O B-geo I-geo O',
#  'O O O O O O B-org O O O O O',
#  'O O O O O O O O O O B-per O O O O',
#  'O O O O O O O B-per I-per O B-per I-per O O O O O O O O O O O O O O O B-geo O O O O O O O O O O O O B-org I-org O O O O O O O O O O O O O',
#  'B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-misc O O O O O O O O O O O',
#  'O O O O B-per I-per O B-per I-per O O B-per I-per O',
#  'O O B-per I-per O O O O O O O O B-geo O O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-geo O O O O B-geo I-geo O O O B-geo O',
#  'O O O O O O O O O B-geo O',
#  'O O O O O B-geo O B-geo O O O O O O O O',
#  'O O B-misc O O O O O O B-geo O O O O O O O O O O B-geo O O O O O B-org I-org O O',
#  'O O O O O B-geo O O O O O B-org I-org O',
#  'O O O O B-geo I-geo O O O O',
#  'O O O O O B-geo I-geo O O B-geo O B-geo O B-geo O O O O B-misc O O B-geo O O B-geo O B-geo O',
#  'O O O O O O O O O O B-geo O O O O O O O B-geo O O O O O O O O O',
#  'O O O O O O O B-geo O O B-geo O O O B-geo O O B-geo O O O',
#  'O O O B-org I-org I-org O O O O O O O B-org O O O O',
#  'O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O B-geo I-geo I-geo O',
#  'O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O B-org I-org I-org O O O O O O O O O O O',
#  'B-per I-per O O O O O O O O O',
#  'O O O O O O O B-geo I-geo O O B-org I-org I-org I-org I-org O',
#  'O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-geo O O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-org I-org O',
#  'O O O O O O O O O O B-misc I-misc I-misc O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-per O O O',
#  'B-per I-per O B-per I-per O B-per I-per O B-per I-per I-per O O B-per I-per O O O O B-org O B-geo O O',
#  'O O O O O O O O B-geo O O O O O O O O O O O O O',
#  'O O O O O O O B-geo I-geo O O B-geo O',
#  'O O O O O O O O O B-org I-org O',
#  'O O O O O O O O O O O O O B-geo I-geo O O O O O O O O O O',
#  'O O O O O O O O O B-geo O B-geo I-geo O',
#  'B-geo O O O O O O O O O O O O O O O O O',
#  'O O O B-org I-org O O O O O O O O O O O O O O B-per I-per O',
#  'O O O B-per I-per O',
#  'O O O O B-geo O B-geo O',
#  'O O O O O O O O O O O O B-geo O O',
#  'O O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-misc I-misc O O O O O O O O B-org I-org I-org O',
#  'O B-org O O O O O O O O',
#  'O O O O B-org I-org I-org O B-org I-org I-org O',
#  'O O O O O O O O O O O O O O O O O O O O O B-per O O O O O O',
#  'O O O O O O B-geo O O O O O O O B-geo O B-geo O B-geo O B-geo O',
#  'O O B-org O O O O O O O O O O',
#  'B-per I-per O O B-geo O O O O O O',
#  'O B-misc O O O O O O O O',
#  'O O O O O O O B-geo O O',
#  'B-misc O B-misc O O O B-geo O B-geo O B-geo O B-geo O B-geo O',
#  'O O O O O O O O O O B-org I-org O O B-org I-org O',
#  'O O O O O O O O B-per I-per O B-per I-per O',
#  'O O O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O O O',
#  'O O O O O O O O B-misc I-misc O O',
#  'B-misc O O O O B-misc O O O O B-geo O B-geo O',
#  'O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O B-per I-per O O B-per I-per O',
#  'O O O O O O O B-org O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O B-org O O O O O O O O O O O O O O O O O',
#  'O B-geo O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-org O O',
#  'O O O O O O O O O O O O O O O B-geo O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-geo I-geo I-geo O O O O O',
#  'O O O O O O O O B-per I-per I-per O O O O B-per I-per O',
#  'O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O',
#  'O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-misc I-misc O',
#  'O O O O O O B-geo O B-geo O B-geo O O B-geo O B-geo O B-geo O O O O',
#  'O O O O B-org I-org I-org I-org O O O O O O B-per I-per O B-per I-per O B-per I-per I-per O O O',
#  'O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-geo O O O O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O O O O',
#  'B-org O O O O O O O O O O O O O O O O O O O O O',
#  'O B-geo I-geo O B-geo O O B-geo I-geo O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-misc I-misc I-misc O O O O O O O O O O O O O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O O B-org I-org O',
#  'B-geo O B-geo O O B-geo I-geo O O O O O O O O O O O O O O O O B-geo O O B-geo O',
#  'O O O O O O O B-geo O O O O O B-org I-org O O O O O O O O O O B-org I-org O O O',
#  'B-geo I-geo O O O O B-geo O O O',
#  'O O O O B-misc I-misc O O O O O O O O O O O O O O O O O O O',
#  'O B-geo I-geo O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O I-misc O O O O O O',
#  'O O O O B-misc O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-geo I-geo I-geo I-geo O',
#  'O O O O O O O O B-per I-per O O O O O O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O B-per I-per O O O O O O O O O O O O',
#  'O O O O O O O B-per I-per O O O O O O O O O O O O O O O O O O',
#  'O B-misc O O O O O O O O B-geo O',
#  'B-per I-per O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O B-per I-per O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-per O O O O O O O O',
#  'O O O O O O O O O O O O B-geo I-geo O O O O O B-geo O O O B-geo I-geo I-geo O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-org O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-misc O O O',
#  'O O O O O O O O O O O B-geo O B-geo O',
#  'O O O O O O O O O O O O B-per I-per O O O O O O O O O',
#  'O O O O O O O O O O O B-misc O O',
#  'O O O O O O O O O O O O O O O O B-org I-org I-org O',
#  'O O O O O O O O O B-per O O O O O O',
#  'O B-geo O O O O O O O O O O O O O O O O O B-misc O B-per I-per O B-per O',
#  'O O O O B-org O O O O O O O B-per I-per O B-per I-per I-per O O O O O O O O O O O O O O O',
#  'O O O B-geo O B-geo O O O O O B-per I-per O O O O B-geo O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O B-per I-per I-per O O O O O O O O O O O O O I-misc O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-geo I-geo O O O O O O O',
#  'O O O O O O O O O O B-geo O',
#  'O O O O O O O O O B-per O O O O O O O O O O O',
#  'B-geo O O O O B-org I-org I-org O O B-org I-org I-org I-org O B-org I-org I-org O O B-org I-org I-org I-org O',
#  'B-geo O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O B-geo O O',
#  'O B-geo O O O O O O O O',
#  'O B-misc O O B-geo O O O O O O',
#  'B-misc O B-misc B-misc O B-misc O B-misc O O O I-misc O O O O O O O O',
#  'O O O O O O O O B-geo O B-geo O B-geo O O B-geo O',
#  'O O O B-geo I-geo I-geo O O B-geo O B-geo O',
#  'O O O O O O B-misc O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-geo I-geo O O B-geo O O',
#  'B-org O O O O O O O O',
#  'O O O O O O B-geo O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-org I-org I-org I-org O O O O O O O O O O O O O O O O O O O O O',
#  'O O B-misc I-misc O O O O O O B-org O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-geo O',
#  'B-per O O O O O O O O O O O O O O',
#  'O O O O O O B-geo I-geo O B-geo O',
#  'O O O O O O O O O O B-per I-per O O O O O O O B-geo O O O O O O',
#  'O O O O O O O O O O O B-misc I-misc I-misc O O O O O O O O O',
#  'O O O B-per O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O I-misc O O O O O O O O O O O O O I-misc I-misc O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc I-misc I-misc O O',
#  'O O O O O O B-geo O O O O O O O O O O O O O O O O O O O',
#  'O B-geo O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-geo O O O O O',
#  'O O O O O O O B-misc O O O O O O O O O O O O O O',
#  'O O O B-misc O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-geo I-geo O O B-org O O O O O O O O O O O O O',
#  'O O B-misc I-misc I-misc O O O O O O O B-org O B-org O O O O O O O O O O O',
#  'O O O O O O O O O O B-geo O B-geo I-geo O',
#  'O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O O O B-geo O O O O O',
#  'O O O O O O O O O O B-org O',
#  'O B-geo I-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc I-misc O B-per I-per O O O O O O B-misc O',
#  'O O O O O B-per I-per I-per O O O O O',
#  'O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-geo O O O O O O O O O O O O O O',
#  'O O O O O O B-geo I-geo O O B-geo O O O O O O B-geo O',
#  'O O O O B-misc I-misc I-misc O O O O O O O O',
#  'O O O O O O O B-geo O B-geo O O O O B-geo O O O O B-geo O O O O B-geo O O O O O O O',
#  'O O O O O B-per I-per O B-per O',
#  'O O O O O B-misc O O O O O O O O O',
#  'B-org O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O B-org O O O O O B-misc I-misc O',
#  'O O O O O O O O O O B-geo O O O O O O B-geo O',
#  'O O O O O O O B-geo O B-geo O B-geo O B-geo O B-geo O B-geo O O O O O O O O O O O O O O O O O B-geo I-geo O B-geo O B-geo O B-geo O B-geo O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-org O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-org I-org O',
#  'O O O O O O O O O O O O O O O O O O O O O O B-org O I-misc O B-org O O O O O O O O O O O O O O O O O O O',
#  'B-per O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-misc O O O B-per I-per O O O',
#  'O O O O O O O O O O O O B-org O O B-org I-org O',
#  'O O O B-per I-per O O O O O O O',
#  'O O O O O O O B-org O O O B-org O O O O O O O O O O O O O O O O O B-org O',
#  'O O O O B-geo I-geo I-geo I-geo I-geo O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O B-misc O O O O O O O O O O O I-misc O',
#  'O O O O O O O O O O O O B-org I-org O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O B-per O O',
#  'B-per O O O O O O O B-per O O O O O O O O O',
#  'B-per I-per O O O O O O O O O',
#  'B-geo O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per I-per I-per O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O B-org I-org O B-org I-org I-org O O O O O O O O O',
#  'O B-misc O O O O O B-misc B-misc O O O O O I-misc I-misc O I-misc I-misc O B-geo O O O O O I-misc I-misc I-misc O I-misc I-misc I-misc O O O O O O O O O O O O I-misc O O I-misc I-misc O O O O B-geo O',
#  'O B-org I-org I-org O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-per I-per O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O B-misc I-misc O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O',
#  'O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O',
#  'O O O O O O O O O O O O B-per I-per O',
#  'O O B-org O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O B-org O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O B-misc O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-per O O O O O O O',
#  'O O O O B-org O O O O O O O O O O O O I-misc O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O B-org O O',
#  'B-org O O O O O O O O O O O O O O O O O',
#  'O O O O B-per O',
#  'O O O O O O B-misc I-misc O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-per I-per O B-per I-per O B-per I-per I-per O',
#  'O O O O O O O O O O O B-per O O',
#  'O O O O B-misc O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per O O',
#  'O O B-org O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-geo O B-geo O O O O O O O O O O O O O O',
#  'O B-geo I-geo O O O O O B-geo I-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-misc O O O O O O O O O B-per I-per O',
#  'B-per O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-per O O O O O O O O',
#  'B-per I-per O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-misc O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O B-per O O O O O',
#  'O O O O B-org I-org I-org O O O O',
#  'O O O O O O O O O O O O O B-geo I-geo O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-geo O B-geo O B-geo O',
#  'O O O O O O O O O O O O O O B-org O O O O O O O O O O O O O O',
#  'O O O O B-org O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-geo O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per O B-per I-per O O O O O',
#  'O O O O O O O O O O B-geo O O O',
#  'O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O O O O O O O B-misc O O O O',
#  'O O O O O O O O O O O O B-misc O O',
#  'O O O O O O O O O O O O O O B-org O O O O',
#  'O O B-per O O B-geo O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-geo I-geo O O O O O O O O B-geo O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O B-per I-per O O O O O O O O O O O O',
#  'O O O O O O O O B-per I-per O B-per I-per O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'B-per I-per O O O O O O O',
#  'O O O O O O O O O O B-misc O O O O O B-misc O',
#  'O O O B-misc I-misc O O O O O O O B-geo O O O O',
#  'O O B-geo O O O O O O B-geo O O O B-geo I-geo I-geo O',
#  'O O O B-per I-per O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-geo O O O O O O B-geo O B-geo O B-geo O B-geo O',
#  'O O B-per O O O O O O O O O',
#  'O O O O B-geo O O O O O',
#  'O O O O O O O O B-misc O O O O O O O B-geo O',
#  'O O O O O O O O O B-per I-per O B-per I-per O B-per I-per O B-per I-per O O O O O O B-misc O O O O O O O O O',
#  'O O O O O O O O O O O B-org I-org I-org O',
#  'O O O O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O B-misc I-misc I-misc I-misc I-misc I-misc O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-geo O O O O O O O O O O O O O O',
#  'O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-org O',
#  'O O O B-per O O O',
#  'O O O B-per I-per O O O O O O O O O O O B-per O O O',
#  'O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-geo O O B-geo O B-geo O B-geo O B-geo O O B-geo O',
#  'O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-org O O O O O O O O O',
#  'O O O O O O O O O O O O B-geo O',
#  'O O B-geo O B-geo O O B-geo O O O O O O O',
#  'O O O O O O O B-misc O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-org O',
#  'O B-org O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-org O O O O O O O O O O O O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O B-geo O O O O O O O O O O O O O O O O O',
#  'O O O O O B-geo O O O O O O O',
#  'O O O O B-misc I-misc I-misc O O O O O O O O',
#  'O B-geo O O O O O O O O O',
#  'O O O O O O B-misc O O O O O O O B-geo O O O O O B-geo O',
#  'O O O O O O O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc O O',
#  'O O O O O O O O O B-geo I-geo I-geo I-geo I-geo I-geo O',
#  'O O O O B-per I-per O',
#  'O O O O O O O O B-geo I-geo O O O O B-per I-per O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-org I-org O',
#  'O O O O O O O O O O B-per O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O B-misc O O',
#  'O B-misc O B-misc O O O O O O O O O O O O',
#  'O O O O O B-org I-org I-org I-org I-org O O O',
#  'B-per O O O O O O O O O O O O O O O',
#  'O B-org O O O O O O O O O O O O O O O O',
#  'O O O B-org O O O O O O B-org O O O O O O O O O',
#  'B-org I-org O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-org O',
#  'O O O O O O O O O O O O B-per I-per O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-per I-per O O O O O I-misc O O O O O O B-misc I-misc O O',
#  'O O B-org I-org I-org O O O B-org O O O O O O O',
#  'O B-per I-per O O O O O O O O O O O O O B-per I-per O',
#  'O O B-per I-per O O O O B-per I-per O O B-per I-per O O B-per I-per I-per I-per O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-org I-org I-org O B-org I-org O B-org O',
#  'O O O O O O O O B-org I-org O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O B-misc I-misc I-misc O O O O O B-geo O O O',
#  'O O O O O O B-per O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O O O O O O O O O B-geo O O B-geo O O O O O O B-per I-per O O O O O O O O O',
#  'O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'B-org O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-per O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O B-geo O O O O O O O O O O O',
#  'O O O B-per I-per O O B-per I-per O O O O O O B-misc B-misc O O O O O O O O',
#  'O O O O B-misc O O O O O O O O O B-geo O B-geo O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-geo O O O O O O O O O O O O O',
#  'O O O B-per O O O O O O O O O O O O O O O O O B-per O O O O O O O O O O',
#  'O B-per I-per O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-per I-per O O B-org I-org I-org O',
#  'O B-org O O O O O O',
#  'O O O O O O O O O O O B-org O O O O O O O O O O O O O',
#  'O O O O O O O O B-org O O O O O O O O',
#  'O O O O O O O O O O O O O B-geo I-geo O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-org O O B-org O O O O O O O O O O O O O B-org O O O O O O O',
#  'O O O O O O O O O O O O B-geo B-per I-per I-per O',
#  'O O O O O O O O B-per O O O O B-misc I-misc I-misc I-misc I-misc O O',
#  'O O O O O O B-misc O O O O O O O',
#  'O O O O B-per I-per O O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo O',
#  'O O O O O O B-org I-org I-org O O O O O O O O O O O O O O',
#  'O O O O B-org O O O O O O O O O O O O O O O O',
#  'O O O O B-misc O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-geo O',
#  'B-org O O O O O O O O O O O O',
#  'O O O O O B-per O O O O O B-misc I-misc I-misc I-misc O O O O O O O O O B-misc I-misc I-misc O O O O O',
#  'O O B-org O O O O O',
#  'O O O O O O O O B-org I-org I-org I-org O B-org I-org I-org O B-org I-org I-org O O B-org I-org I-org I-org O',
#  'O O O O B-org I-org I-org I-org I-org O O O O O O O O O O O',
#  'O O O O B-geo O B-geo O B-geo I-geo O O O O B-geo O O B-geo O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-org I-org O O B-org O',
#  'O B-geo O O O O O O O O O',
#  'O O O O O O O O O B-org I-org O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-org O B-geo O O O O',
#  'O O O O O O O O O B-org O',
#  'O O O O O O O B-misc O O B-per I-per O',
#  'O O O O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O O O O O O I-misc I-misc O I-misc I-misc O O O O B-geo I-geo O O O O O O O O O O O',
#  'B-per O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-geo O O O O O O O O O',
#  'O O O O O O O O O O O O O B-misc O O',
#  'O O O O O O O O O O B-misc O O O B-per I-per O',
#  'O O O O O O B-per I-per I-per O O O O O O O B-per O O O O B-per O',
#  'O O O O O O O O O B-misc I-misc I-misc I-misc O O O O O',
#  'O O B-per I-per O O O B-org O O O O O B-per I-per O O O O O B-misc I-misc O O B-per I-per O',
#  'O O O O O O B-geo O O O O O B-org O',
#  'O O O O B-misc O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O B-per I-per O O O O O O O O O',
#  'O O O B-org O O O O O O O O O',
#  'O O O B-per O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-org I-org I-org O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-per O O O B-misc I-misc I-misc I-misc O O',
#  'O O O O O O O O O O O O O O O O O O O O O B-per O O O O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O B-misc I-misc O O O O O O O O O O B-misc O O O O O O O O O O',
#  'O O O O O O O O B-geo I-geo O O O O',
#  'O O O O O O B-geo O O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-per I-per O O O O O O O B-org I-org O O B-per O O O O O O O O',
#  'O B-geo I-geo O O O O O O O',
#  'O O O O O O O O B-geo O O O',
#  'O O B-per O O O O O O B-geo O',
#  'O O B-misc I-misc I-misc I-misc O B-org I-org I-org O O O O B-org O O O O O O O',
#  'O O O O O O O B-misc O O O O O O O O B-misc O O',
#  'O O O O O B-per O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-geo I-geo O B-geo I-geo O O B-geo I-geo O',
#  'O O O O O O O O B-misc O O O',
#  'B-geo O O O O O O O O O O O O O O B-geo I-geo O O O O O O O O',
#  'O O B-misc I-misc O O O O O O O O O O O O O O O O O O O B-geo I-geo O B-geo O',
#  'O O O O O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O B-geo O O O O O O O O B-geo I-geo O',
#  'O B-per O B-per O O O O O O O O B-per O O B-geo O B-per O O O O O O O B-geo O B-geo O B-geo O B-geo O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O',
#  'B-geo O O O O O O O O O O O O O O O',
#  'O O O O B-geo O O O O O O O O O',
#  'O O O O O O O O O O O O B-org I-org O O O O O O O',
#  'B-per O O O O B-geo O O O',
#  'O O O O O O B-org O B-org O O O',
#  'O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-per I-per O O O O O O O O O O O O O O O O B-per I-per O O O',
#  'B-per O O O O B-per O O O O O O O O O O O O O O O O O O',
#  'O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo I-geo O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-per O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-misc O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O B-per O O O O O O O O O O O O',
#  'O O O O O O B-misc I-misc I-misc O',
#  'O O O O O O O O O O O B-geo I-geo I-geo I-geo I-geo I-geo O O O O B-geo I-geo I-geo I-geo I-geo I-geo O',
#  'O O O O O B-geo I-geo I-geo O O O O O O O O O B-geo O O B-geo O O O O O O',
#  'O B-misc O O O O O O O O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-per O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O B-geo O O O O O O O O O O O O O O O',
#  'O O B-geo O B-geo O O O O O O O O O',
#  'O O O O O O O O O O B-per O O O',
#  'O O O O O O O B-geo O O O O O O O O B-per I-per O',
#  'O O B-geo O B-geo O O O O O B-org I-org O O B-org O',
#  'O O O O O O O O O O O B-geo I-geo O O O O O O O O',
#  'O O O O O O O O O B-geo O O O O O O O O O O O O',
#  'O O O O B-misc O O O O O O O O',
#  'O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O',
#  'O O O O B-per I-per O B-per I-per O',
#  'O O O O O B-per I-per O O O B-misc I-misc I-misc I-misc I-misc I-misc O O O O O',
#  'O O O O O O O O O O O O O B-geo O',
#  'O O O O B-geo O O O O O O',
#  'O O O O O O O B-per I-per O O O O O O',
#  'O O O O B-per I-per O O O O O',
#  'O O O O O O B-geo O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-org O',
#  'O O O O O B-per O O O O B-per O',
#  'O O O O O O O O O O O O O O O B-per I-per O O O O',
#  'O O O O O O O O O O O B-per I-per O B-per I-per O O O O O B-per I-per O',
#  'O O O O O O O B-geo O I-misc O B-geo O B-geo O O I-misc O O O O O O B-geo O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-geo O B-geo O O O O O O O O O',
#  'O O O O O B-misc O O O O O O',
#  'O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-misc O O',
#  'O O B-misc O O O O O B-misc O O O O O O O O O O O O O O',
#  'O O O O O O O O B-misc B-misc O O O O O O O O',
#  'O O O O O O O O O O B-per O O O B-per O O O O O O O O O O',
#  'O O O B-misc I-misc I-misc I-misc O O O O O O O O O B-misc I-misc I-misc O',
#  'O O O O O O B-per I-per O O B-misc O O O B-geo I-geo I-geo O',
#  'O O O O O O O O O B-misc I-misc O O O O O O O O O O B-per O O O',
#  'O O O O O O B-geo I-geo O O O O O',
#  'O B-org O O B-org O O O O O O O O O O O O O B-per O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-misc O O O O O O O O',
#  'B-per I-per O O O O O O',
#  'O O B-misc I-misc O B-per O O O O O O O O O O O O',
#  'O O O O O O O B-misc O O O O O',
#  'O O O O O O O O O O O O O O O O O O B-per O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O B-geo O O O O O O O O B-misc O O O O O O O O O O',
#  'O O O O B-per O O O O O O O',
#  'O O O O O O B-org O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O O B-org O O O O O B-misc I-misc I-misc I-misc O O O O O O O O O O O O O O',
#  'O O O O O O B-per I-per O O O O O O O',
#  'O O O O O O O O O O O B-per O B-per O O O O O O O',
#  'O O O B-org O O O',
#  'O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-org I-org I-org O O O O O O B-per O O O O O O O O O O B-misc O O O O O O',
#  'O O O O O O O O O O O O O O O B-geo I-geo O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O',
#  'O O O O O O O O O O O O B-org I-org I-org O O O O O O B-per O O O B-geo O O B-geo I-geo I-geo I-geo I-geo O O O O O',
#  'O O O O O B-geo I-geo O O O O O O O O O O',
#  'O O O O O O O O O O O B-misc O O O B-geo I-geo O',
#  'O O O O B-per I-per O B-per I-per O O B-per I-per O',
#  'O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-geo O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-org O O O O O O O O B-misc I-misc I-misc I-misc I-misc O',
#  'O O O O O O O O O O O O O O O B-org O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O',
#  'O O O O O O B-geo I-geo O B-per I-per O O O O O O O O O O O O O O O O O O',
#  'O O O O B-per O O O O O O O O O O O O O O O B-per O O O O O O',
#  'O O O O O O O O O O O O O O O O B-per I-per O',
#  'O O B-per I-per O O O O B-org I-org I-org I-org O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-misc O',
#  'O O O O O B-per I-per I-per O B-per I-per O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-per I-per O O O O',
#  'O O O O O O O B-misc I-misc O O O O O O O O O',
#  'O B-geo O O O O O O O O O',
#  'O O O O O O O B-misc O O O',
#  'O O O O O O O O O O O O O B-per I-per O O O O O O O',
#  'O O O O O O O O O B-misc O O O O O O O O O O O O O O O O B-geo O O',
#  'O O B-org O O O O O O B-per I-per O O O O O O O O O O O',
#  'O O O B-misc O O O O O O O O O O O O O O O O O',
#  'B-misc I-misc O O O O O O O O O O O O O O O O O O',
#  'O O O B-per I-per O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-geo O O O O O O O',
#  'O O O O O O O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-misc O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O B-org I-org O O O O O O',
#  'O O O O O O O O O B-misc O O O O O O O O O',
#  'O O O O O O O O O B-org I-org O',
#  'O O O O O O O O O O O O O O O O O O O O O B-misc O O O B-misc O O',
#  'O O O O O O O B-geo O O O O O O O O O O O',
#  'O O O O O O O O O O B-per O B-per O B-per O B-per O',
#  'O O O O O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-misc O O O O O O O O',
#  'O O O O B-geo I-geo O O O O O B-geo O O O O O O O O O O O',
#  'O O O O O B-misc O O O O O O O O O',
#  'O O O O O O O O O B-misc I-misc I-misc O',
#  'O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O O O O O O O O O O O O B-misc O O O O O O O O',
#  'O O B-misc I-misc I-misc O O O O O O O O',
#  'O B-misc I-misc I-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O B-org O',
#  'O O O O O O O O O O O B-geo O O O O O O O O O O B-org O B-org O B-org O B-org O B-org O',
#  'O O O O O O O B-geo I-geo O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-org I-org O B-org I-org O',
#  'O O O O O O O O O O O B-geo O O B-geo O O O O O O O O O O',
#  'O O O B-misc I-misc O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-misc O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O B-misc I-misc I-misc O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-per O O',
#  'O O O O O O O O O B-geo O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-geo I-geo I-geo I-geo O O O O',
#  'O O O O O B-org I-org I-org I-org I-org I-org I-org O B-org O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo O O O O O O B-geo I-geo I-geo O',
#  'O O O O O O O O O O O O O O O O O O B-geo I-geo O O O O O O O B-geo O B-geo I-geo O',
#  'O O O O O O O O O O O B-geo O O',
#  'O O O O O O O O O O O O O O B-geo O B-org O O O O O O O O O O O B-org O O O O O O O O O',
#  'O B-org O O O O O O O O O O O O O O',
#  'O B-geo O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-misc O O O O O O O O O O O',
#  'B-per I-per O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O O O O B-misc I-misc I-misc I-misc O O O O O O O',
#  'B-org O O O O O O O O O O O O O O O O O',
#  'B-per I-per O O O O O B-misc O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-geo I-geo O O O O O O O O O O O O O O O O O O',
#  'O O B-per I-per O O O O O O O O O O O O O O O O O O O B-per O O O O O',
#  'O O O O O O O O B-geo O O O O O O O O O O O O O B-per I-per O O O O O',
#  'O O O O O O B-org I-org O O O',
#  'O O O O O O O O O O O B-per O O O O O O O O B-geo O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo O O O O',
#  'O O O O O B-org O O O O O O O O O O O O O',
#  'O O O O B-org I-org I-org O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-org I-org I-org I-org I-org I-org I-org O O O O O O O O O O O O',
#  'O O O O O O B-per O B-per I-per O B-per I-per O B-per I-per O B-per I-per O',
#  'O O O O O O O B-per I-per O O B-per I-per I-per O O B-misc O O O O O O O B-org I-org O O',
#  'O O O O O O O B-per I-per I-per O O O O O O O O O B-per I-per I-per O O O O O O O O O O B-per O O B-per O O O B-per O',
#  'O O O O O O B-per O B-per O O O O O',
#  'O B-org I-org I-org I-org O B-org O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-per I-per O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O B-org I-org O',
#  'O O B-per I-per O B-per I-per O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc I-misc I-misc O O O O O O O O O O',
#  'O O O O B-org I-org I-org O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-per I-per O',
#  'O O O O O B-per I-per O O O O O O O O',
#  'O O O O O O B-org O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo I-geo O',
#  'O B-org O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'B-per I-per O O O O O O B-per I-per O',
#  'O O O O O O O B-per O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-geo O O O O O O O O O',
#  'B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-org I-org I-org I-org I-org I-org I-org I-org O O B-org I-org I-org I-org I-org O O O O O O O O O',
#  'B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-org O B-geo O B-org O O O O O',
#  'O O B-geo O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O B-misc I-misc I-misc I-misc I-misc O O O B-per O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-misc I-misc I-misc O O O O O O O O O',
#  'O O O O O O O O O O O O O B-org I-org I-org O',
#  'O O B-org I-org O O O O O O O O O O O O O O O B-per I-per O O O O O O O O',
#  'O O O O O O B-geo O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per O O O O O O O O O',
#  'O O O O O O O O O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O O O O',
#  'O O O O B-per O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-per O O O O O O O O O O B-per O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-geo O O O O O B-geo O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-org O O O O O O O O',
#  'B-misc O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-misc I-misc I-misc I-misc O O O O O B-misc I-misc I-misc O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-per I-per O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O B-misc I-misc I-misc I-misc I-misc O O O B-misc I-misc I-misc O O O O O O',
#  'O O O O O O O B-misc O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-org O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per O',
#  'B-per I-per O O O O',
#  'O O O O O O O O O O O B-misc O O O O O O O O B-misc O O O O',
#  'O O O O O O O B-misc I-misc O O O O O B-org O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O',
#  'O O O B-misc O O O O O O O O O O O O O O O O O O O',
#  'B-org O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-misc O O O O O O O O O O',
#  'O O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O O O O O O O O O O B-org I-org I-org O',
#  'O O O O O O O O O O O O O O O I-misc I-misc I-misc O O B-per O O O O O',
#  'O O O B-geo O O O O O O O O O O O',
#  'O O O B-per I-per O O O O O B-geo O O O O O O B-geo I-geo O O B-geo I-geo O O B-geo I-geo I-geo I-geo O O O O O O O O O O O O',
#  'O O O B-misc O B-misc O B-misc O O O O O O O',
#  'O O O O O O O O O O O B-org I-org O O O',
#  'B-geo O O O O O O O O O B-per I-per O B-geo O O O',
#  'O O O O O O O O O O O O O O B-geo O O O O O O',
#  'O O O O O O O O B-misc O O O O O O O O O O O O O O O I-misc I-misc O O',
#  'O O O O O O O O O O B-misc I-misc O',
#  'O O O O O B-misc I-misc I-misc O O O O O B-per I-per O O O O O O O O',
#  'O O O O O O O O O O O O B-misc O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-org O',
#  'O O O O O O O O O O B-misc O O O O O O O O O O O O O O',
#  'O O O O O O O O B-per I-per O O O O B-misc O O',
#  'O O B-geo O O O O O O O O O O O',
#  'O O O O O O O O O B-geo I-geo O O B-geo I-geo I-geo O B-geo I-geo I-geo O',
#  'O O O O O O O O B-per I-per O O O O O O O B-misc I-misc I-misc O',
#  'B-per O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc I-misc I-misc O O',
#  'O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O B-per I-per I-per O O O B-geo O O',
#  'O O O O O O O O O O O O O O O B-misc O O O O O B-misc I-misc O O O O O O O O O O O',
#  'O O O O O B-geo O O O B-per I-per O O O O O O B-org O B-geo O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O O O B-per I-per I-per O',
#  'O O O O O O O O O O O O O O O O O O O O O B-org I-org I-org O O O O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-per I-per O O O O O B-org O O O O O O O',
#  'O O O O O O O B-misc I-misc I-misc I-misc I-misc I-misc O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O O B-misc I-misc I-misc I-misc O O',
#  'O O O O O O O O O B-org I-org O O O O O O O O O O O B-per I-per O B-per I-per O',
#  'O O O O O O O O B-geo O O O O O O B-per I-per O O O O O O I-misc O O O O O O O O O O O O B-org O O O O O B-org O O O B-org O O',
#  'O B-per I-per O O O O O O O O O O O O O O O O O',
#  'O B-misc O O O',
#  'B-geo O O O O O O B-geo I-geo O O O O B-geo I-geo O O O B-geo O O O B-geo O O O B-geo O',
#  'O O O O O B-org I-org O O O O O B-org I-org I-org O O O O O O O O O O O O O O O B-misc I-misc I-misc O O O',
#  'O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O B-geo O O O O O',
#  'O O O O O O O O O O O O O O O B-per I-per I-per O O O O O O O O O O',
#  'O O O O O O O O O O O B-geo O O B-geo I-geo O',
#  'O O O O O O O O O O O O O O O O O O O O B-geo O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-org I-org O',
#  'O O O O O O O B-per O O O O O O O O O O O O O',
#  'O O O O O O O B-org O O O B-misc O O',
#  'O O O O O O O O O O B-org O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-misc I-misc I-misc O',
#  'O O O O O O O O O O B-org I-org I-org I-org I-org O B-org O O B-org I-org I-org I-org O O O O',
#  'O O O O B-org I-org I-org O O O O O O O O O O O B-org O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O B-geo O O B-geo O O B-geo O O B-geo O O O O O O O',
#  'O O O O O B-geo O O O O O',
#  'B-org I-org O O O O O O O O O O O O O O O B-org I-org O B-org I-org I-org I-org O',
#  'O O O O O B-org I-org I-org I-org I-org O B-org O O O O O O O O O O B-geo O',
#  'B-geo O O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-misc O O O O O O O',
#  'O O O O B-misc O O O B-misc O O',
#  'O O B-org I-org I-org I-org O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-org O B-org O O B-org I-org I-org O B-org O O O O O O O O O O O O O',
#  'O O O B-per I-per O O O O O O B-per O O B-per O B-per O O O',
#  'O O O O O O O O O O O O O O O B-per I-per O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O B-per I-per I-per I-per I-per O O O O I-misc I-misc O O O O O O O O O O',
#  'O O O B-geo I-geo O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O B-geo O B-geo O O B-org I-org O O O',
#  'O O O O O B-per I-per O',
#  'O O O O O O O O O O O O O O O O B-geo O B-geo O B-geo O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O I-misc O O O O O B-geo O B-geo I-geo O O O B-geo O B-geo O',
#  'O O O O O O O O O O B-per I-per I-per O O O O O',
#  'O O O O O O B-geo O B-geo O B-geo O B-geo O B-geo O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O O O O O O O O B-org I-org I-org I-org O O O O O B-org I-org O O B-geo I-geo O O O O O O O O',
#  'O O O O O O O B-misc O O',
#  'O O O O O B-org O O O O O O O B-org O O',
#  'O O O O O O O O O B-org I-org I-org O O O O O O O O O O O O O O O O O O O O O',
#  'B-geo O O O O O O O O O O',
#  'O O O O O O O O B-geo O O O O O',
#  'O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-org O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O B-geo I-geo O O O O',
#  'O O O O O O B-org I-org I-org O O O O O O O',
#  'O O O O O O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-per I-per O B-per I-per O O B-per I-per O O O O O O O O O O O O B-per I-per O O O O O',
#  'O O O O O O O O O B-org O B-org O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-misc O O O',
#  'O O O O O B-geo O B-geo O B-geo O B-geo O B-geo O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O B-per O',
#  'O O O O O O O O O B-misc O O O O O O O',
#  'O O O O O O B-org I-org I-org O B-org O O O O O B-org O O B-geo I-geo I-geo I-geo I-geo O B-geo O O',
#  'O O O O O O O O O B-geo O B-geo O B-geo O O B-geo O',
#  'B-per O O O O O O O O O O O O',
#  'B-org I-org O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-org O O B-per I-per O O O O O O',
#  'O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-misc I-misc I-misc O O O O O O O O O',
#  'O O O O O O O B-per I-per O O O O O O O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc O O',
#  'O O B-misc O O O B-misc I-misc I-misc I-misc O O O O O O O O O O B-misc O O O O O O O B-per I-per O',
#  'O O O O O O O O O O O O O B-org I-org O O O O O',
#  'O O O O O O O O O O B-misc O O O O O O O O O O O B-per O O O O O O O O O O',
#  'O O O O O B-misc O O B-org I-org O',
#  'O O O O O O O O O O O O O O B-misc I-misc I-misc I-misc O O',
#  'O B-geo O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-org I-org I-org O O O B-org O O O O O O',
#  'O O O O O O O O O O B-misc I-misc I-misc I-misc I-misc I-misc O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O B-per O O O O B-per O O O O B-per O O O O B-per O O O O O O O O O O O O O O O O O O',
#  'O O O O B-per I-per O O O O',
#  'O O O O O O O B-misc I-misc I-misc I-misc I-misc O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo O B-per I-per O B-per I-per O O O O O O O O O O O O O',
#  'O O O O O B-org O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-misc I-misc I-misc I-misc O',
#  'B-geo O O O O O O O O',
#  'O O O O O O O O O O O O O B-org I-org O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-org I-org O B-org I-org O',
#  'O O B-per O O O O O',
#  'O O O O O O O B-misc O O O O O B-org O',
#  'O O O B-org O O O O O O O O O O O O O O B-per I-per O',
#  'O B-per I-per O O O O O O O O O O O O O O O O',
#  'O O O O O O B-per I-per I-per O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O B-geo O O B-geo I-geo I-geo O O O O O O O O B-geo O',
#  'B-geo O O O O O O O O',
#  'O O O O O B-misc I-misc I-misc O O O O O O O O O O',
#  'B-geo O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O B-org I-org O',
#  'O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-misc O O O O O O',
#  'O B-org O O O O O O O O O O O O B-misc I-misc I-misc O O O B-per I-per O B-per I-per O B-per I-per O',
#  'O B-org O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-per I-per O O B-per I-per O',
#  'O O O O O O O O O O B-org O O O O O O O O',
#  'O O O O O O O O O O O O O O B-geo I-geo O O O O O O O O O O O O O O O O O',
#  'B-per I-per O O O B-per I-per O O O O O O O O B-org O O O O O B-org O O',
#  'O B-org O O O O O O B-org I-org I-org I-org O O B-org I-org I-org O O O',
#  'O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-org I-org O O O O O',
#  'O O O O B-geo O O O O O O B-org O B-org O B-org O O O O O B-org I-org O B-org O B-org O',
#  'B-geo O O O O O O O O O O',
#  'O O O O O O O B-misc I-misc O B-misc I-misc I-misc O O B-misc I-misc I-misc O O O O O',
#  'O O O O O O O B-org I-org O O O O O O O O',
#  'O B-org I-org I-org O O O O O O O B-geo O',
#  'O B-misc O O O O O O O O O O',
#  'O O O O O O B-org I-org O O O O O O O O O O O O O O O O O',
#  'O O B-misc I-misc O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-per I-per O O O B-misc I-misc I-misc I-misc O O',
#  'O O O O O O O O O O O O B-org I-org O O O O O O O O O O O O O O O O O O',
#  'O O O O B-per O B-geo I-geo O B-per I-per I-per O',
#  'O O O O O O O B-per I-per O O O O O O O',
#  'O O O O O O O O O O O B-misc I-misc O',
#  'O O O O O O O O B-org I-org I-org O',
#  'O O O O O O B-geo O',
#  'O O O O O O B-org I-org O',
#  'O O O O O O O O O O O O O O B-geo O O O O',
#  'O O O O O O B-org I-org I-org O O O O O O O O O O O O',
#  'O O O B-geo O',
#  'O O O O O O O O O O O B-misc O O O',
#  'O O O O O O O O O O O O B-geo O O O O O O O O O O O O O',
#  'O B-org O O O B-per O O O O O O O O O O O',
#  'O O B-misc I-misc I-misc I-misc O O O O O O O O O O O O O O O O',
#  'O O O B-geo O O O O O O O O O O O O O O O O O B-geo I-geo O',
#  'O O O O O B-geo O',
#  'O O O O O O B-org I-org I-org O O O O O O O O O O O O O B-org I-org O',
#  'O O O O O O O O O B-org I-org I-org I-org O B-geo I-geo O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O B-geo O O O O O O O O B-org O B-geo O O O O O B-org O',
#  'O O O O O O O O O B-geo I-geo I-geo I-geo I-geo I-geo O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-org I-org I-org O',
#  'O O O O O O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O',
#  'O O O O O O O O O O B-geo I-geo I-geo O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O O O O O O O O O',
#  'O O B-geo O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O B-geo O O',
#  'O O O O O O O O O O O O B-geo O B-geo O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-misc O O O O O O O O O O O',
#  'O O O O O O O O O O B-misc O O O B-org I-org I-org O O O O O O',
#  'O O O O O O O O O O O O O O O B-per O B-per O O O O O O O O I-misc O',
#  'O O O O O O O O O B-geo I-geo O O O O O',
#  'O O O O B-org I-org O O O O O O O O O O O O O O O O',
#  'O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-geo O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-org I-org I-org O O O O O O O O O O B-org I-org O O O O O O O O O O O O B-org I-org I-org O O O O O O O O O O O B-org I-org O O O O',
#  'O O O O O O O O O B-per O O O O O O',
#  'O O O O O O O O O O O B-geo O O O O O O O O O',
#  'O O B-misc I-misc O O O O O O O O O O O',
#  'O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O B-org I-org I-org O',
#  'O O O O B-org O O O O O O O O O O O O B-misc I-misc I-misc I-misc O O O O O O O O B-misc O O O O O O O B-misc I-misc O O O O O O O O B-per I-per O O O O O',
#  'O O O O O O O B-org O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-per I-per O B-per I-per O',
#  'O O O O O O O O O O B-geo O B-geo O B-geo O B-geo O B-geo O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O B-geo I-geo O O B-geo I-geo O',
#  'O O O O O B-geo O O O O O O O O O O O',
#  'O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-per I-per I-per I-per O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-per I-per O O B-org I-org O O O O',
#  'O O O O O O O O O O O O O O B-misc O O O O O O O O O O O O O B-misc O O O O O B-misc O O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-geo I-geo O O O O O O B-geo O',
#  'O O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-misc O B-misc O B-misc O',
#  'O O O O B-misc O O O B-misc O O',
#  'O O O O O O O O O B-geo O O O O O O O O O O',
#  'O O B-per I-per O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-misc I-misc I-misc O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-per O O O O O B-per O O O O O O O O',
#  'O B-misc I-misc O O O O O O O O O I-misc O O',
#  'O O O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O O O B-misc I-misc I-misc O O O',
#  'O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O B-org I-org I-org O',
#  'O O O O O O O O O O B-misc I-misc O O O O O O O O O O O O O O O',
#  'B-org I-org I-org O O B-misc O O O O O O O I-misc I-misc O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-org O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-geo O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O B-per I-per O',
#  'O O B-misc I-misc I-misc O B-geo I-geo O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O B-geo O O O O O O O O O O O O O O O',
#  'O O O O B-misc I-misc I-misc O O O O O O O B-misc I-misc I-misc O',
#  'O O O O O O O O O O O O O O O O O O O B-misc I-misc I-misc O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O B-geo O',
#  'O O O O O O O O O O O O O O O B-org I-org O O O O O O',
#  'B-per O O O O B-per O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O B-org I-org O O O B-org I-org I-org O O O O O O B-org I-org O O',
#  'O O B-misc O B-per I-per O O O O O O O O O O O O O O O O O O O O O O B-per O',
#  'O O O O O O B-per O O O O O O O O',
#  'O O O O O O O O O O O O O B-org I-org O O O O O O O O',
#  'O O O O O B-misc I-misc I-misc O O O O O O O O O O O',
#  'O O O O O O B-per I-per O O O O O O O O O O O O',
#  'O O O B-geo I-geo O O O O',
#  'O O O O O O O B-org I-org I-org O O O O O O O O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O O O O O',
#  'O B-misc I-misc I-misc O O O O O O',
#  'O B-geo O O O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per O B-per I-per O O O O O O O B-per I-per O O O O O O O O O O O O O O O O O O B-per I-per O',
#  'O O O O O B-per I-per O O O O O O O O O B-per O O O O O O B-org O O O O O I-misc I-misc O O',
#  'O O O O O O B-org O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O B-misc O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O B-misc I-misc I-misc I-misc O O O O O O O O O O O O O O O O O O',
#  'O B-per I-per O O O O O O O O O O O O O O O O',
#  'O O O O O O B-org O O O O O O',
#  'O O O O O O O O O O B-geo O',
#  'B-misc O O O O O O O O O O O O',
#  'B-geo O O O B-geo O',
#  'B-per O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O B-misc I-misc I-misc O O',
#  'O O O O O O O O B-org I-org O B-geo O',
#  'B-misc O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O B-geo O O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O O O O O O O O B-per I-per I-per O',
#  'O O O O B-misc O O O O O O O O O O B-misc O O',
#  'O B-misc B-misc O O O O O O O O O O',
#  'O O O B-misc O O O O O O O O O O O O O O O O O',
#  'O O B-misc I-misc I-misc O B-misc I-misc I-misc O B-geo O O O O O O O B-geo O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O B-org I-org I-org I-org I-org O O',
#  'O O O O O O O O B-geo O O O O O B-geo O O O O O O O O O',
#  'O O O O O O O B-per O O O O O O O O',
#  'O O O O O O O O O O O B-per I-per O O O O O O',
#  'O B-misc I-misc I-misc O B-geo O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O B-geo I-geo B-per I-per O',
#  'O O O O O O O O O O O O O O O B-org I-org I-org O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-misc O O',
#  'O O O O O O B-org O O O O O O O O O O O O O O',
#  'O O O O O O O O B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O O O B-per O O O O O O O O O O',
#  'O O O O O O O B-misc I-misc O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O B-per I-per O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O B-geo O O',
#  'O B-per O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-per O B-per I-per O O O O O O O',
#  'O O O O O O B-geo O B-geo O O O O O O O O O O',
#  'O O O O B-per I-per O O O O O O O O O O O B-misc I-misc O O O O O O O O O O O O B-per I-per O O B-misc I-misc I-misc I-misc O O O O',
#  'O O O B-per I-per I-per O O B-geo O O O O O O O O O',
#  'O O O O O O O B-misc B-misc O O O O O O O B-geo O O O O O O B-misc O B-misc B-misc O',
#  'O O O O O O O O O O B-org O O O O B-geo O B-geo O O',
#  'O O O O O B-org I-org O O O O O O O B-org I-org I-org I-org O B-org O O O O O O O O O O I-misc O O O O',
#  'O O O O O O O O O O B-geo O O O O O B-geo O B-geo O O O O O O O O',
#  'O O O O O O O O O B-geo O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-per I-per O O O O O O O O O O',
#  'O O O O O B-misc O B-geo O O O O O O O O O',
#  'O O O O O O O O O O O O O B-org I-org I-org I-org I-org O O',
#  'O O B-per O O O',
#  'O O O O B-geo I-geo O O O O O O',
#  'O O B-misc I-misc I-misc O O O O O O O O O O B-org I-org O O O O O O O O O O O O B-geo O',
#  'O O O B-geo O O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O B-misc O O O O O',
#  'O O O O O O O O B-misc O O O O O',
#  'B-geo O O O O O O O O O O O O O O O O O',
#  'O B-misc I-misc I-misc O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'B-per I-per O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O O O O O O O B-per O O O O O O O O O B-per O O O',
#  'O B-org O O O O O B-org O B-org O O O',
#  'O B-geo I-geo O O O O O O O O O O O B-geo O O O O O O O O O O O O O O O O O O O O O',
#  'B-misc O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O B-org I-org O O O O O O O O O O O O O O O O O O O O O O O O',
#  'O O B-per I-per I-per O O O O O O O O O O',
#  'O O O O O O O O O O O O O O O O B-geo O O O',
#  'O O O O O B-geo O O B-geo O O O',
#  'B-per I-per I-per O O O O O O B-misc I-misc I-misc O O O O O O O O O',
#  'O O O O B-geo O O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-org I-org O',
#  'O O O O O O O B-org I-org O O B-misc I-misc I-misc O O O O B-per I-per I-per O O O O O O O O O O O O O O',
#  'O O O O O O O B-geo O O O O O O O O O O O B-geo O B-geo O',
#  'O O O O O O O O O O O O O O O O O O B-misc O O',
#  'O O O O O O O O O O O O O O O B-geo I-geo O O O O',
#  'B-per O O O O O O O O O O O O O O O O',
#  'O O O O O O O O O O O O O B-geo O',
#  'O O O O O O O O O O B-per I-per I-per O B-geo O',
#  'O O O O O O B-geo O O O O O B-per I-per O O O O B-per O',
#  'O B-misc I-misc I-misc O O O O O O O O O O O O O O',
#  'O O B-misc I-misc I-misc I-misc O O O O O O O O O O O O O O O I-misc I-misc I-misc O O O O O O O O O O O',
#  'O O O O O O O O O O O O B-org O O O B-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc I-misc O O O O O O O O O O O',
#  'O O O O O B-geo O O O O O O',
#  'O O O O O O B-org I-org I-org O B-org O',
#  'O O O O O O O B-per I-per O O O O O O O O O O O',
#  'O O O O B-per I-per O O O O O O O O O O O O O',
#  'B-geo O O O O O O O O O B-geo O',
#  'O O O O O O B-geo O O O O O B-geo O',
#  'O O O O O O O O B-org O O O O O O O O O O O O O O O O O O O O O O O',
#  ...]

# %%
import csv

with open('ner2.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerows(zip(texts, tags2))

# %%
import pandas as pd

df = pd.read_csv('ner2.csv')
df
# Out:
#       This division also contains the Ventana Wilderness , home to the California condor .  \
# 0      " So here is the balance NBC has to consider :...
# 1      It is a protest song that " creates a cinemati...
# 2      This differs from approaches such as IP or Eth...
# 3      Since then , only Terry Bradshaw in 147 games ...
# 4      Next is the Adolf-Hitler-Platz , a grand publi...
# ...                                                  ...
# 92714  The couple had a son , David , and a daughter ...
# 92715  The Home Secretary , J. R. Clynes , was presen...
# 92716  At the time of her birth , she was fourth in t...
# 92717  The film was based on the Broadway play of the...
# 92718  The couple had two children ( both born by Cae...
#
#                  O O O O O B-geo I-geo O O O O B-geo O O
# 0      O O O O O O B-org O O O O B-misc I-misc O O B-...
# 1      O O O O O O O O O O O O O O O O O O O O O O O ...
# 2                 O O O O O O O O B-misc O O O O O O O O
# 3      O O O O B-per I-per O O O O B-per I-per O O O ...
# 4                        O O O B-geo O O O O O O O O O O
# ...                                                  ...
# 92714                O O O O O O B-per O O O O O B-per O
# 92715          O O O O B-per I-per I-per O O O O O O O O
# 92716    O O O O O O O O O O O O O O O O O B-per I-per O
# 92717                     O O O O O O B-misc O O O O O O
# 92718  O O O O O O O O O B-misc O O B-per O O O O B-p...
#
# [92719 rows x 2 columns]

# %%
headerList = ['text', 'labels']
  
# converting data frame to csv
df.to_csv("ner2.2.csv", header=headerList)
  
# display modified csv file
df2 = pd.read_csv("ner2.2.csv")
df2 = df2.drop(['Unnamed: 0'], axis=1)
df2.columns = ['text', 'labels']

# %%
df2
# Out:
#                                                     text  \
# 0      " So here is the balance NBC has to consider :...
# 1      It is a protest song that " creates a cinemati...
# 2      This differs from approaches such as IP or Eth...
# 3      Since then , only Terry Bradshaw in 147 games ...
# 4      Next is the Adolf-Hitler-Platz , a grand publi...
# ...                                                  ...
# 92714  The couple had a son , David , and a daughter ...
# 92715  The Home Secretary , J. R. Clynes , was presen...
# 92716  At the time of her birth , she was fourth in t...
# 92717  The film was based on the Broadway play of the...
# 92718  The couple had two children ( both born by Cae...
#
#                                                   labels
# 0      O O O O O O B-org O O O O B-misc I-misc O O B-...
# 1      O O O O O O O O O O O O O O O O O O O O O O O ...
# 2                 O O O O O O O O B-misc O O O O O O O O
# 3      O O O O B-per I-per O O O O B-per I-per O O O ...
# 4                        O O O B-geo O O O O O O O O O O
# ...                                                  ...
# 92714                O O O O O O B-per O O O O O B-per O
# 92715          O O O O B-per I-per I-per O O O O O O O O
# 92716    O O O O O O O O O O O O O O O O O B-per I-per O
# 92717                     O O O O O O B-misc O O O O O O
# 92718  O O O O O O O O O B-misc O O B-per O O O O B-p...
#
# [92719 rows x 2 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/ner.csv')
df
# Out:
#                                                     text  \
# 0      Thousands of demonstrators have marched throug...
# 1      Iranian officials say they expect to get acces...
# 2      Helicopter gunships Saturday pounded militant ...
# 3      They left after a tense hour-long standoff wit...
# 4      U.N. relief coordinator Jan Egeland said Sunda...
# ...                                                  ...
# 47954  Opposition leader Mir Hossein Mousavi has said...
# 47955  On Thursday , Iranian state media published a ...
# 47956  Following Iran 's disputed June 12 elections ,...
# 47957  Since then , authorities have held public tria...
# 47958  The United Nations is praising the use of mili...
#
#                                                   labels
# 0      O O O O O O B-geo O O O O O B-geo O O O O O B-...
# 1      B-gpe O O O O O O O O O O O O O O B-tim O O O ...
# 2      O O B-tim O O O O O B-geo O O O O O B-org O O ...
# 3                                  O O O O O O O O O O O
# 4      B-geo O O B-per I-per O B-tim O B-geo O B-gpe ...
# ...                                                  ...
# 47954  O O O B-per I-per O O O O O O O O O O O O O O ...
# 47955  O B-tim O B-gpe O O O O O O O O B-org I-org O ...
# 47956  O B-geo O O B-tim I-tim O O O O O O O O O O O ...
# 47957          O O O O O O O O O O O O O O O O O O O O O
# 47958  O B-org I-org O O O O O O O O O O O O O O B-ti...
#
# [47959 rows x 2 columns]

# %%
df.columns = ['text', 'labels']

# %%
#combining datasets
df = pd.concat([df, df2], ignore_index=True, axis=0)

# %%
df
# Out:
#                                                      text  \
# 0       Thousands of demonstrators have marched throug...
# 1       Iranian officials say they expect to get acces...
# 2       Helicopter gunships Saturday pounded militant ...
# 3       They left after a tense hour-long standoff wit...
# 4       U.N. relief coordinator Jan Egeland said Sunda...
# ...                                                   ...
# 140673  The couple had a son , David , and a daughter ...
# 140674  The Home Secretary , J. R. Clynes , was presen...
# 140675  At the time of her birth , she was fourth in t...
# 140676  The film was based on the Broadway play of the...
# 140677  The couple had two children ( both born by Cae...
#
#                                                    labels
# 0       O O O O O O B-geo O O O O O B-geo O O O O O B-...
# 1       B-gpe O O O O O O O O O O O O O O B-tim O O O ...
# 2       O O B-tim O O O O O B-geo O O O O O B-org O O ...
# 3                                   O O O O O O O O O O O
# 4       B-geo O O B-per I-per O B-tim O B-geo O B-gpe ...
# ...                                                   ...
# 140673                O O O O O O B-per O O O O O B-per O
# 140674          O O O O B-per I-per I-per O O O O O O O O
# 140675    O O O O O O O O O O O O O O O O O B-per I-per O
# 140676                     O O O O O O B-misc O O O O O O
# 140677  O O O O O O O O O B-misc O O B-per O O O O B-p...
#
# [140678 rows x 2 columns]

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
label_all_tokens = False

def align_label(texts, labels):
    tokenized_inputs = tokenizer(texts, padding='max_length', max_length=512, truncation=True)

    word_ids = tokenized_inputs.word_ids()

    previous_word_idx = None
    label_ids = []

    for word_idx in word_ids:

        if word_idx is None:
            label_ids.append(-100)

        elif word_idx != previous_word_idx:
            try:
                label_ids.append(labels_to_ids[labels[word_idx]])
            except:
                label_ids.append(-100)
        else:
            try:
                label_ids.append(labels_to_ids[labels[word_idx]] if label_all_tokens else -100)
            except:
                label_ids.append(-100)
        previous_word_idx = word_idx
    #print(label_ids)
    return label_ids

class DataSequence(torch.utils.data.Dataset):

    def __init__(self, df):

        lb = [i.split() for i in df['labels'].values.tolist()]
        #print(lb)
        txt = df['text'].values.tolist()
        #print(txt)
        self.texts = [tokenizer(str(i),
                               padding='max_length', max_length = 512, truncation=True, return_tensors="pt") for i in txt]
        self.labels = [align_label(i,j) for i,j in zip(txt, lb)]

    def __len__(self):

        return len(self.labels)

    def get_batch_data(self, idx):

        return self.texts[idx]

    def get_batch_labels(self, idx):

        return torch.LongTensor(self.labels[idx])

    def __getitem__(self, idx):

        batch_data = self.get_batch_data(idx)
        batch_labels = self.get_batch_labels(idx)

        return batch_data, batch_labels

# %%
df = df[:140677]

labels = [i.split() for i in df['labels'].values.tolist()]
print(labels)
unique_labels = set()

for lb in labels:
        [unique_labels.add(i) for i in lb if i not in unique_labels]
labels_to_ids = {k: v for v, k in enumerate(unique_labels)}
ids_to_labels = {v: k for v, k in enumerate(unique_labels)}
print(ids_to_labels) 

df_train, df_val, df_test = np.split(df.sample(frac=1, random_state=42),
                            [int(.8 * len(df)), int(.9 * len(df))])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
 class BertModel(torch.nn.Module):

    def __init__(self):

        super(BertModel, self).__init__()

        self.bert = BertForTokenClassification.from_pretrained('bert-base-cased', num_labels=len(unique_labels))

    def forward(self, input_id, mask, label):

        output = self.bert(input_ids=input_id, attention_mask=mask, labels=label, return_dict=False)

        return output

# %%
def train_loop(model, df_train, df_val):

    train_dataset = DataSequence(df_train)
    val_dataset = DataSequence(df_val)

    train_dataloader = DataLoader(train_dataset, num_workers=4, batch_size=BATCH_SIZE, shuffle=True)
    val_dataloader = DataLoader(val_dataset, num_workers=4, batch_size=BATCH_SIZE)

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)

    if use_cuda:
        model = model.cuda()

    best_acc = 0
    best_loss = 1000

    for epoch_num in range(EPOCHS):

        total_acc_train = 0
        total_loss_train = 0

        model.train()

        for train_data, train_label in tqdm(train_dataloader):

            train_label = train_label.to(device)
            mask = train_data['attention_mask'].squeeze(1).to(device)
            input_id = train_data['input_ids'].squeeze(1).to(device)

            optimizer.zero_grad()
            loss, logits = model(input_id, mask, train_label)
            for i in range(logits.shape[0]):

              logits_clean = logits[i][train_label[i] != -100]
              label_clean = train_label[i][train_label[i] != -100]

              predictions = logits_clean.argmax(dim=1)
              acc = (predictions == label_clean).float().mean()
              total_acc_train += acc
              total_loss_train += loss.item()

            loss.backward()
            optimizer.step()

        model.eval()

        total_acc_val = 0
        total_loss_val = 0

        for val_data, val_label in val_dataloader:

            val_label = val_label.to(device)
            mask = val_data['attention_mask'].squeeze(1).to(device)
            input_id = val_data['input_ids'].squeeze(1).to(device)

            loss, logits = model(input_id, mask, val_label)

            for i in range(logits.shape[0]):

              logits_clean = logits[i][val_label[i] != -100]
              label_clean = val_label[i][val_label[i] != -100]

              predictions = logits_clean.argmax(dim=1)
              acc = (predictions == label_clean).float().mean()
              total_acc_val += acc
              total_loss_val += loss.item()

        val_accuracy = total_acc_val / len(df_val)
        val_loss = total_loss_val / len(df_val)

        print(
            f'Epochs: {epoch_num + 1} | Loss: {total_loss_train / len(df_train): .3f} | Accuracy: {total_acc_train / len(df_train): .3f} | Val_Loss: {total_loss_val / len(df_val): .3f} | Accuracy: {total_acc_val / len(df_val): .3f}')

LEARNING_RATE = 0.005
EPOCHS = 3
BATCH_SIZE = 2

model = BertModel()
train_loop(model, df_train, df_val)
# Out:
# Downloading:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# 100%|██████████| 56271/56271 [59:38<00:00, 15.73it/s]
# Epochs: 1 | Loss:  0.699 | Accuracy:  0.864 | Val_Loss:  0.697 | Accuracy:  0.863
# 100%|██████████| 56271/56271 [59:47<00:00, 15.69it/s]
# Epochs: 2 | Loss:  0.696 | Accuracy:  0.864 | Val_Loss:  0.703 | Accuracy:  0.863
# 100%|██████████| 56271/56271 [59:53<00:00, 15.66it/s]
# Epochs: 3 | Loss:  0.696 | Accuracy:  0.864 | Val_Loss:  0.701 | Accuracy:  0.863

# %%
def evaluate(model, df_test):

    test_dataset = DataSequence(df_test)

    test_dataloader = DataLoader(test_dataset, num_workers=4, batch_size=1)

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    if use_cuda:
        model = model.cuda()

    total_acc_test = 0.0

    for test_data, test_label in test_dataloader:

            test_label = test_label.to(device)
            mask = test_data['attention_mask'].squeeze(1).to(device)

            input_id = test_data['input_ids'].squeeze(1).to(device)

            loss, logits = model(input_id, mask, test_label)

    
            for i in range(logits.shape[0]):

              logits_clean = logits[i][test_label[i] != -100]
              label_clean = test_label[i][test_label[i] != -100]

              predictions = logits_clean.argmax(dim=1)
              acc = (predictions == label_clean).float().mean()
              total_acc_test += acc
            

  
    val_accuracy = total_acc_test / len(df_test)
    print("val_accuracy", val_accuracy)
    print(f'Test Accuracy: {total_acc_test / len(df_test): .3f}')
    


evaluate(model, df_test)
# Out:
# val_accuracy tensor(0.8631, device='cuda:0')
# Test Accuracy:  0.863

# %%
def align_word_ids(texts):
  
    tokenized_inputs = tokenizer(texts, padding='max_length', max_length=512, truncation=True)

    word_ids = tokenized_inputs.word_ids()

    previous_word_idx = None
    label_ids = []

    for word_idx in word_ids:

        if word_idx is None:
            label_ids.append(-100)

        elif word_idx != previous_word_idx:
            try:
                label_ids.append(1)
            except:
                label_ids.append(-100)
        else:
            try:
                label_ids.append(1 if label_all_tokens else -100)
            except:
                label_ids.append(-100)
        previous_word_idx = word_idx

    return label_ids


def evaluate_one_text(model, sentence):


    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    if use_cuda:
        model = model.cuda()
      
    words = sentence.split()

    text = tokenizer(sentence, padding='max_length', max_length = 512, truncation=True, return_tensors="pt")

    mask = text['attention_mask'].to(device)
    input_id = text['input_ids'].to(device)
    label_ids = torch.Tensor(align_word_ids(sentence)).unsqueeze(0).to(device)

    logits = model(input_id, mask, None)
    logits_clean = logits[0][label_ids != -100]
    
    predictions = logits_clean.argmax(dim=1).tolist()
    prediction_label = [ids_to_labels[i] for i in predictions]

    prediction_dict = dict(zip(words, prediction_label))
    

    #print(sentence)
    #print(prediction_label
    return prediction_dict

# %% [markdown]
# Dialogue System

# %%
travel_detail = ["Name", "Origin", "Destination", "Date of Travel", "Time of Travel", "Return Date", "Return Time" ]

frames = dict(zip(travel_detail, [None]*len(travel_detail)))
data =[frames]
print(frames)
print(data)
# Out:
# {'Name': None, 'Origin': None, 'Destination': None, 'Date of Travel': None, 'Time of Travel': None, 'Return Date': None, 'Return Time': None}
# [{'Name': None, 'Origin': None, 'Destination': None, 'Date of Travel': None, 'Time of Travel': None, 'Return Date': None, 'Return Time': None}]

# %%
def chat():
  travel_detail = ["Name", "Origin", "Destination", "Date of Travel", "Time of Travel" ]
  frames = dict(zip(travel_detail, [None]*len(travel_detail)))
  data =[]
  name = ""
  dest = ""
  origin = ""
  DateofTravel = ""
  time = ""
  returnDate = ""
  returntime = ""
  print("Agent: Hi, do you want to book a flight ticket? [Reply Yes or No]")
  response = input()
  if response == "Yes" or response == "yes":
    print("Agent: Nice, lets get you started, What is your name?")
    name_response = input()
    nameResponse_label = evaluate_one_text(model, name_response)
    #print(nameResponse_label)
    for key, value in nameResponse_label.items():
      if "B-per" == value:
        name = key
      if "I-per" == value:
        name = name +" " +key
    frames["Name"] = name

    print("Agent: Where do you want to travel?")
    destination_response = input()
    destinationResponse_label = evaluate_one_text(model, destination_response)
    #print(destinationResponse_label)
    for key, value in destinationResponse_label.items():
      if "B-geo" == value:
        dest = key
      if "I-geo" == value:
        dest = dest +" " +key 
    frames["Destination"] = dest

    print("Agent: What is your place of origin?")
    origin_response = input()
    originResponse_label = evaluate_one_text(model, origin_response)
    #print(originResponse_label)
    for key, value in originResponse_label.items():
      if "B-geo" == value:
        origin = key
      if "I-geo" == value:    
        origin = origin +" " +key 
    frames["Origin"] = origin

    print("Agent: What day do you want to travel? [example: 12th December 2022]")
    DoT_response = input()
    DoTResponse_label = evaluate_one_text(model, DoT_response)
    #print(DoTResponse_label)
    for key, value in DoTResponse_label.items():
      if "B-tim" == value:
        DateofTravel = key
      if "I-tim" == value:    
        DateofTravel = DateofTravel +" " +key 
    frames["Date of Travel"] = DateofTravel
    frames["Date of Travel"] = DoT_response

    print("Agent: What time of the day do you want to travel? [example: morning, afternoon, evening]")
    time_response = input()
    timeResponse_label = evaluate_one_text(model, time_response)
    
    #print(timeResponse_label)
    for key, value in timeResponse_label.items():
      if "B-tim" == value:
        time = key
      if "I-tim" == value:    
        time = time +" " +key 
    frames["Time of Travel"] = time
    frames["Time of Travel"] = time_response

    print("Agent: Do you want a return ticket?[Reply Yes or No]")
    returnresponse = input()
    if returnresponse == "Yes" or returnresponse == "yes":
      print("Agent: When do you want to return?[example: 12th December 2022]")
      return_date = input()
      returnDateResponse_label = evaluate_one_text(model, return_date)
      #print(returnDateResponse_label)
      for key, value in returnDateResponse_label.items():
        if "B-tim" == value:
          returnDate = key
        if "I-tim" == value:    
          returnDate =  returnDate +" " +key 
      frames["Return Date"] =  returnDate
      frames["Return Date"] =  return_date
         
      print("Agent: What time of the day do you want your return flight? [example: morning, afternoon, evening] ")
      returnTime_response = input()
      returnTimeResponse_label = evaluate_one_text(model, returnTime_response)
      #print(returnTimeResponse_label)
      for key, value in returnTimeResponse_label.items():
        if "B-tim" == value:
          returntime = key
        if "I-tim" == value:    
          returntime = returntime +" " +key 
      frames["Return Time"] = returntime
      frames["Return Time"] = returnTime_response
    else:
      data.append(frames)
      for key, value in frames.items():
        if "None" == value:
          print("Agent: More Information needed")
          
  
  for key, value in frames.items():
    if "None" == value:
      print("Agent: More Information needed")

  data.append(frames)
  print("Thank you")

  return frames, data

# %%
frames, data = chat()
# Out:
# Agent: Hi, do you want to book a flight ticket? [Reply Yes or No]
# yes
# Agent: Nice, lets get you started, What is your name?
# Nancy Drew
# Agent: Where do you want to travel?
# London
# Agent: What is your place of origin?
# Indianapolis
# Agent: What day do you want to travel? [example: 12th December 2022]
# 12rh December 2923
# Agent: What time of the day do you want to travel? [example: morning, afternoon, evening]
# morning
# Agent: Do you want a return ticket?[Reply Yes or No]
# no
# Thank you
